# %% [markdown]
# <a href="https://colab.research.google.com/github/athp18/BrewBuddy/blob/main/DataTeachWorkshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hands On Introduction to Computer Vision
#
# ## Goal of this notebook
#
# We want to learn computer vision! We'll start off with some basic operations using OpenCV and build up to running a deep learning model off our webcam.

# %% [markdown]
# ## A few basic libraries:
#
# - **PyTorch**: A deep learning library developed by Meta.
# - **OpenCV**: An optimized computer vision library!
# - **NumPy**: A library for efficient linear algebra and computation!
# - **PIL (Python Imaging Library)**: A library for image processing!
# - **os**: A library for basic operating system commands!
# - **Matplotlib**: A library for displaying and plotting!

# %% [markdown]
# Before we get started, let's download a few images and datasets to make things easier for ourselves.

# %%
# !wget "https://www.dropbox.com/scl/fi/usx4p53x7uo634ojcpooz/images.zip?rlkey=iu6cgqobyfdass69tx6gfmvtg&st=3arrx070&dl=1" -O images.zip
# !unzip images.zip -x "__MACOSX/*" "*.DS_Store"
# Out:
# --2024-10-30 20:36:47--  https://www.dropbox.com/scl/fi/usx4p53x7uo634ojcpooz/images.zip?rlkey=iu6cgqobyfdass69tx6gfmvtg&st=3arrx070&dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.6.18, 2620:100:6028:18::a27d:4712
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.6.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc990210fc2d5fcfbbee08efe768.dl.dropboxusercontent.com/cd/0/inline/CdcDg-6tuBwHwj1xCGz6rBOUih2PIZo0l8xYOzm7I8n54So9QuV8B697RG1Pwc415FkXatw5_8TIJH0y8RxzLBP8lFrZTClVHt2S251wYbR5EEiZ_c1BUBvMypIV4Ud4obbmrf0YWYSL3zBswaZbH__-/file?dl=1# [following]
# --2024-10-30 20:36:48--  https://uc990210fc2d5fcfbbee08efe768.dl.dropboxusercontent.com/cd/0/inline/CdcDg-6tuBwHwj1xCGz6rBOUih2PIZo0l8xYOzm7I8n54So9QuV8B697RG1Pwc415FkXatw5_8TIJH0y8RxzLBP8lFrZTClVHt2S251wYbR5EEiZ_c1BUBvMypIV4Ud4obbmrf0YWYSL3zBswaZbH__-/file?dl=1
# Resolving uc990210fc2d5fcfbbee08efe768.dl.dropboxusercontent.com (uc990210fc2d5fcfbbee08efe768.dl.dropboxusercontent.com)... 162.125.71.15, 2620:100:601c:15::a27d:60f
# Connecting to uc990210fc2d5fcfbbee08efe768.dl.dropboxusercontent.com (uc990210fc2d5fcfbbee08efe768.dl.dropboxusercontent.com)|162.125.71.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CdcKD-P4UaLSkrNNOMV3SKhMWgJkGOAQB-5mo4Qe-IfJkd7NMovstuoQjhnWw4PO4jCOLBaRKfcPsM8hAiZLr7OV8484zmWxw8zutBm8suqFJfoHeDngevax0cT1ygnXfRbKklrGaSBaNrTMkTJWzOgwasExQA__TCKm7bN8CWWbXVps6epm3Y3P3PJY81jbhv7avmEkQwqJxs5091DyHJRdTICCc81sSTNrp18AHBrqULE7QPfIunWwTAZI0mbQ3lYaZhHqudKIEYF_VfXDu1siKS_X9mvRB2u0ml6aEUwyzQPI2Q8fNBXlIxWcL4ld4gxLJVoW0LpCPWXpcvHWok_nN4gNS9s2dnAMRHlYdsnf3cqlhH6q3YiMkHfHRl94c60/file?dl=1 [following]
# --2024-10-30 20:36:50--  https://uc990210fc2d5fcfbbee08efe768.dl.dropboxusercontent.com/cd/0/inline2/CdcKD-P4UaLSkrNNOMV3SKhMWgJkGOAQB-5mo4Qe-IfJkd7NMovstuoQjhnWw4PO4jCOLBaRKfcPsM8hAiZLr7OV8484zmWxw8zutBm8suqFJfoHeDngevax0cT1ygnXfRbKklrGaSBaNrTMkTJWzOgwasExQA__TCKm7bN8CWWbXVps6epm3Y3P3PJY81jbhv7avmEkQwqJxs5091DyHJRdTICCc81sSTNrp18AHBrqULE7QPfIunWwTAZI0mbQ3lYaZhHqudKIEYF_VfXDu1siKS_X9mvRB2u0ml6aEUwyzQPI2Q8fNBXlIxWcL4ld4gxLJVoW0LpCPWXpcvHWok_nN4gNS9s2dnAMRHlYdsnf3cqlhH6q3YiMkHfHRl94c60/file?dl=1
# Reusing existing connection to uc990210fc2d5fcfbbee08efe768.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3902587 (3.7M) [application/binary]
# Saving to: ‘images.zip’
#
# images.zip          100%[===================>]   3.72M  3.96MB/s    in 0.9s
#
# 2024-10-30 20:36:52 (3.96 MB/s) - ‘images.zip’ saved [3902587/3902587]
#
# Archive:  images.zip
#    creating: images/
#   inflating: images/antelope.jpg
#   inflating: images/deer.jpg
#   inflating: images/elephant.jpg
#   inflating: images/cow.jpg
#   inflating: images/panda.jpg
#   inflating: images/chihuahua.jpg
#   inflating: images/collie.jpg
#   inflating: images/squirrel.jpg
#   inflating: images/giraffe.jpg
#   inflating: images/fox.jpg
#   inflating: images/bear.jpg

# %%
# !zip -r imgs.zip ./images -x "*/\.*" "*/\.ipynb_checkpoints/*"
# Out:
# updating: images/ (stored 0%)
# updating: images/randompuppy.jpg (deflated 18%)
# updating: images/coins.jpg (deflated 5%)
# updating: images/elephant.jpg (deflated 2%)
# updating: images/doggy.png (deflated 2%)
# updating: images/antelope.jpg (deflated 1%)
# updating: images/chihuahua.jpg (deflated 1%)
# updating: images/fox.jpg (deflated 1%)
# updating: images/giraffe.jpg (deflated 1%)
# updating: images/puppy.jpg (deflated 16%)
# updating: images/blackpuppy.jpg (deflated 6%)
# updating: images/squirrel.jpg (deflated 1%)
# updating: images/pupp.jpg (deflated 3%)
# updating: images/collie.jpg (deflated 0%)
# updating: images/pup.jpg (deflated 5%)
# updating: images/deer.jpg (deflated 1%)
# updating: images/bear.jpg (deflated 1%)
# updating: images/cow.jpg (deflated 2%)
# updating: images/panda.jpg (deflated 1%)

# %% [markdown]
# ### Basic Linear Algebra
#
# - The foundation of machine learning and computer vision is a **matrix**.
#
# ![Image of Matrix](https://dcvp84mxptlac.cloudfront.net/diagrams2/equation-1-example-of-a-matrix.png)
#
# A matrix is just a way to organize numbers. For example, mathematically, say we have two equations: x + y = 12 and 2x + 3y = 26. We can organize the coefficients and constants as a 2x3 matrix, like this:
#
# ![matrix_image.png](data:image/png;base64,...)
#
# An image too can be represented as a matrix. A few examples to show this below:

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('./images/panda.jpg')
image_raw = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

plt.imshow(image_gray)
plt.axis('off')
plt.show()

# %%
from google.colab.drive import mount

mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print(image_gray)
# Out:
# [[ 85 100 101 ...  78  78  82]
#  [ 82  91 102 ...  81  77  73]
#  [ 94  89 101 ...  86  80  79]
#  ...
#  [118  91  89 ... 112 114 113]
#  [ 99  88  89 ... 118 121 120]
#  [ 90  87  91 ... 122 120 122]]

# %%
print(image_raw[:3]) # truncate so we don't show everything
# Out:
# [[[ 96  83  67]
#   [111  98  82]
#   [112  99  83]
#   ...
#   [ 68  80  92]
#   [ 70  79  94]
#   [ 74  83 100]]
#
#  [[ 93  79  66]
#   [102  88  75]
#   [113 100  84]
#   ...
#   [ 74  83  92]
#   [ 73  77  88]
#   [ 72  72  84]]
#
#  [[104  92  78]
#   [ 99  87  73]
#   [112  98  85]
#   ...
#   [ 80  87  95]
#   [ 77  80  85]
#   [ 79  78  84]]]

# %%
print("Shape of the raw image", image_raw.shape)
print("Shape of the grayscale image", image_gray.shape)
# Out:
# Shape of the raw image (768, 1024, 3)
# Shape of the grayscale image (768, 1024)

# %% [markdown]
# What can we see from this? In a grayscale image, each entry of the matrix is represented by a single value indicating how "gray" the image is. In a regular, color image, each entry has 3 values, corresponding to red, green, and blue. Each value has a range from 0 to 255, corresponding to how much color is in the image.

# %% [markdown]
# The matrix above can be represented in Python in several ways:
#
# ```
# - numpy.array([1,1,12],[2,3,26])
# - torch.tensor([1,1,12], [2,3,26])
# - [[1,1,12], [2,3,26]]
# ```
# The first is a Numpy array (or the foundation for OpenCV, which we'll get to soon). The second is a PyTorch tensor (the foundation for PyTorch), which have been optimized for GPU operations. And the third is a regular Python list -- what you'll probably use out of most data science contexts :)

# %% [markdown]
# So! Let's do it ourselves!

# %%
#@title Helper Functions
# Function to add a subplot with relative size visualization
def add_subplot_with_relative_size(position, img, title):
    ax = fig.add_subplot(gs[position])

    # Create a background to show original image dimensions
    background = np.zeros((height, width, 3), dtype=np.uint8) + 240  # Light gray background

    # Calculate position to center the transformed image
    img_h, img_w = img.shape[:2]
    y_offset = (height - img_h) // 2
    x_offset = (width - img_w) // 2

    # Place the transformed image on the background
    if img_h <= height and img_w <= width:
        background[y_offset:y_offset+img_h, x_offset:x_offset+img_w] = img
    else:
        # For rotated image that might exceed bounds, crop it
        visible_h = min(img_h, height)
        visible_w = min(img_w, width)
        background = img[:visible_h, :visible_w]

    ax.imshow(background)
    ax.set_title(title)

    # Add dotted lines to show original dimensions
    ax.axhline(y=0, color='gray', linestyle=':', alpha=0.5)
    ax.axhline(y=height-1, color='gray', linestyle=':', alpha=0.5)
    ax.axvline(x=0, color='gray', linestyle=':', alpha=0.5)
    ax.axvline(x=width-1, color='gray', linestyle=':', alpha=0.5)

# %%
# Exercise 1: Loading and printing basic info about an image with OpenCV
import numpy as np

image_path = './images/bear.jpg'
img = cv2.imread(image_path)
print(f"Image shape: {img.shape}")
print(f"Data type: {img.dtype}") # what command should we use to find the data type?
print(f"Min value: {img.min()}, Max value: {img.max()}") # how can we find the minimum of an array?


# Now say we want to break an image and apart and stitch it together? How can we do so?
red_channel = img[:, :, 0]
green_channel = img[:, :, 1]
blue_channel = img[:, :, 2]
restitched_image = np.stack((red_channel, green_channel, blue_channel), axis=2).astype(np.uint8)

plt.figure(figsize=(20, 4))

# Original image
plt.subplot(151)
plt.imshow(image)
plt.title('Original Image')
plt.axis('off')

# Red channel
plt.subplot(152)
plt.imshow(red_channel)
plt.title('Red Channel')
plt.axis('off')

# Green channel
plt.subplot(153)
plt.imshow(green_channel)
plt.title('Green Channel')
plt.axis('off')

# Blue channel
plt.subplot(154)
plt.imshow(blue_channel)
plt.title('Blue Channel')
plt.axis('off')

# Restitched image
plt.subplot(155)
plt.imshow(restitched_image)
plt.title('Restitched Image')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
# Exercise 2: Basic Image Operations
'''
Goal: Understand how to apply basic image operations
Learning outcomes:
- Resizing
- Cropping
- Rotating
'''

# Load the image
image = cv2.imread('./images/fox.jpg')
if image is None:
    raise ValueError("Could not load the image. Please check the file path.")

# Convert the image from BGR to RGB
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Get image dimensions
height, width = image.shape[:2]

# 1. Resizing the Image
scale_percent = 50  # percent of original size
new_width = int(width * scale_percent / 100)
new_height = int(height * scale_percent / 100)
resized_image = cv2.resize(image, (new_width, new_height), interpolation=cv2.INTER_AREA)

# 2. Cropping the Image
crop_size = min(200, height, width)  # Ensure crop size doesn't exceed image dimensions
center_y, center_x = height // 2, width // 2
half_crop = crop_size // 2

start_y = center_y - half_crop
start_x = center_x - half_crop
end_y = center_y + half_crop
end_x = center_x + half_crop

cropped_image = image[start_y:end_y, start_x:end_x]

# 3. Rotating the Image
center = (width // 2, height // 2)
rotation_matrix = cv2.getRotationMatrix2D(center, 45, 1.0)
rotated_image = cv2.warpAffine(image, rotation_matrix, (width, height))

# Create figure
fig = plt.figure(figsize=(20, 5))
gs = plt.GridSpec(1, 4, figure=fig)
images = [
    (image, 'Original Image\n' + f'({width}x{height})'),
    (resized_image, f'Resized Image\n({new_width}x{new_height})'),
    (cropped_image, f'Cropped Image\n({crop_size}x{crop_size})'),
    (rotated_image, 'Rotated Image (45°)\n' + f'({width}x{height})')
]

for idx, (img, title) in enumerate(images):
    add_subplot_with_relative_size(idx, img, title)

plt.tight_layout()
plt.axis('off')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load images
dog_image = cv2.imread('./images/pup.jpg')
dog_image = cv2.cvtColor(dog_image, cv2.COLOR_BGR2RGB)
coin_image = cv2.imread('./images/coins.jpg')
coin_image_rgb = cv2.cvtColor(coin_image, cv2.COLOR_BGR2RGB)

# Dog Image Processing Steps
# Step 1: Apply Gaussian Blur
dog_gaussian_blur = cv2.GaussianBlur(dog_image, (7, 7), 5)

# Step 2: Convert to Grayscale
dog_gray = cv2.cvtColor(dog_gaussian_blur, cv2.COLOR_RGB2GRAY)

# Step 3: Apply Canny Edge Detection
dog_edges = cv2.Canny(dog_gray, 100, 200)

# Step 4: Find and Draw Contours
dog_contours, _ = cv2.findContours(dog_edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
dog_image_with_contours = dog_image.copy()
cv2.drawContours(dog_image_with_contours, dog_contours, -1, (255, 0, 0), 2)

# Display Dog Image Processing Steps in a Row
plt.figure(figsize=(20, 5))
plt.subplot(1, 4, 1)
plt.imshow(dog_image)
plt.title("Original Dog Image")
plt.axis('off')

plt.subplot(1, 4, 2)
plt.imshow(dog_gaussian_blur)
plt.title("Gaussian Blur")
plt.axis('off')

plt.subplot(1, 4, 3)
plt.imshow(dog_edges, cmap='gray')
plt.title("Canny Edge Detection")
plt.axis('off')

plt.subplot(1, 4, 4)
plt.imshow(dog_image_with_contours)
plt.title("Contours on Dog Image")
plt.axis('off')

plt.tight_layout()
plt.show()

# Coin Image Processing Steps
# Step 1: Create a black background mask for coins
coin_gray = cv2.cvtColor(coin_image, cv2.COLOR_BGR2GRAY)
_, binary_mask = cv2.threshold(coin_gray, 240, 255, cv2.THRESH_BINARY_INV)
black_bg = coin_image_rgb.copy()
black_bg[binary_mask == 0] = [0, 0, 0]

# Step 2: Grayscale and Gaussian Blur for Contour Detection
gray_black_bg = cv2.cvtColor(black_bg, cv2.COLOR_RGB2GRAY)
coin_blurred = cv2.GaussianBlur(gray_black_bg, (9, 9), 2)

# Step 3: Find Contours
coin_contours, _ = cv2.findContours(coin_blurred, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Filter contours based on area to reduce noise
min_contour_area = 1000
filtered_contours = [cnt for cnt in coin_contours if cv2.contourArea(cnt) > min_contour_area]
coin_count = len(filtered_contours)

# Draw Contours on Original and Black Background
coin_output_black = black_bg.copy()
coin_output_original = coin_image_rgb.copy()
for contour in filtered_contours:
    cv2.drawContours(coin_output_black, [contour], -1, (0, 255, 0), 2)
    cv2.drawContours(coin_output_original, [contour], -1, (0, 255, 0), 2)

# Display Coin Image Processing Steps in a Row
plt.figure(figsize=(20, 5))
plt.subplot(1, 4, 1)
plt.imshow(coin_image_rgb)
plt.title("Original Coin Image")
plt.axis('off')

plt.subplot(1, 4, 2)
plt.imshow(black_bg)
plt.title("Black Background Mask")
plt.axis('off')

plt.subplot(1, 4, 3)
plt.imshow(coin_output_black)
plt.title("Contours on Black Background")
plt.axis('off')

plt.subplot(1, 4, 4)
plt.imshow(coin_output_original)
plt.title(f"Contours on Original Image: {coin_count} coins")
plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Now to implement our CartoonGAN!
#
# CartoonGAN is based on a standard Generative Adversarial Network, but instead of just predicting between fake and real images, it also has to distinguish between smoothed cartoon images. As a result of this, CartoonGAN tends to avoid the problem that a lot of GANs trained on cartoons have, where images can appear overly smoothed.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import AdamW
from torch.optim.lr_scheduler import CyclicLR
import torchvision.utils as vutils

from datetime import datetime
import numpy as np
import cv2
from PIL import Image
import matplotlib.pyplot as plt
import pickle
import os

# %%
from google.colab.drive import mount
mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !wget -O smoothed_cartoons.zip "https://www.dropbox.com/scl/fi/w2xpvrsqdhya1j1wunpoe/smoothed_cartoons.zip?rlkey=tr4vm7knz27kwfbax3di5z5fq&st=hgyfzlar&dl=1"
# !wget -O coco.zip "https://www.dropbox.com/scl/fi/oh0lsqhlf6kdbcrglhewf/coco_images.zip?rlkey=ltrlb1fnemfxhvixzcsnbbbaf&st=3vf59pp4&dl=1"
# !wget -O cartoons.zip "https://www.dropbox.com/scl/fi/pcjnxskeju656k6kmkgtx/cartoons.zip?rlkey=iq2gpqy0q2dvpi8u3htfvyo97&st=byr3wr59&dl=1"
# Out:
# --2024-10-30 22:39:28--  https://www.dropbox.com/scl/fi/w2xpvrsqdhya1j1wunpoe/smoothed_cartoons.zip?rlkey=tr4vm7knz27kwfbax3di5z5fq&st=hgyfzlar&dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.6.18, 2620:100:6019:18::a27d:412
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.6.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc52d79f4a55d545a2d5c7e4823a.dl.dropboxusercontent.com/cd/0/inline/Cdd1WF9bcCH5nVTDv1I9pzux0_O7OsSqw7Q9P8hhMeaAI4TG91OlyuKiZ3Qvrd1zQou93KuB-q5FRHc0OL84gYLt787x7VQ-8CApvkrmMb0iI6hCKUp6FBp8tGoItXd5rGLmy_ZZ6EqpkQsitXJbTpr1/file?dl=1# [following]
# --2024-10-30 22:39:29--  https://uc52d79f4a55d545a2d5c7e4823a.dl.dropboxusercontent.com/cd/0/inline/Cdd1WF9bcCH5nVTDv1I9pzux0_O7OsSqw7Q9P8hhMeaAI4TG91OlyuKiZ3Qvrd1zQou93KuB-q5FRHc0OL84gYLt787x7VQ-8CApvkrmMb0iI6hCKUp6FBp8tGoItXd5rGLmy_ZZ6EqpkQsitXJbTpr1/file?dl=1
# Resolving uc52d79f4a55d545a2d5c7e4823a.dl.dropboxusercontent.com (uc52d79f4a55d545a2d5c7e4823a.dl.dropboxusercontent.com)... 162.125.6.15, 2620:100:6019:15::a27d:40f
# Connecting to uc52d79f4a55d545a2d5c7e4823a.dl.dropboxusercontent.com (uc52d79f4a55d545a2d5c7e4823a.dl.dropboxusercontent.com)|162.125.6.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CdfSDpsbY_aMX6Rfo1B2lQhB19f6dQpfF085EjhXkx90lr4SOhspEn7W13leQO9EJDVE-r3rdnxnxyLrBbF8C9LVhjE3Ev44KNEA5q6StnUwLlZJwjq2cdRf6lkX6H2yWCSEmJO2mo3Z6Mh7hRqAAYS9luyBjnu07pwOTiSxjm2Mzyn4UkNQzI7KhpSBFekKl6hxfV0YWyExhiiRkRCnfKQDFnWaqnBVqZPNBU1ItEOeL4ixSCEtT37EYKELp534WA7LRNPF2z3Mkc1Eal-zrBinlJF661SFvJLW9f-exAW1BzyfRQ7Cgkgt2nDB77M5IurA_zA-qi3WOyuB1QOU25CRVmW5iYQbGfFrBT-aTdJAUrbgJ5p-cHzE0bZyG_DV5To/file?dl=1 [following]
# --2024-10-30 22:39:30--  https://uc52d79f4a55d545a2d5c7e4823a.dl.dropboxusercontent.com/cd/0/inline2/CdfSDpsbY_aMX6Rfo1B2lQhB19f6dQpfF085EjhXkx90lr4SOhspEn7W13leQO9EJDVE-r3rdnxnxyLrBbF8C9LVhjE3Ev44KNEA5q6StnUwLlZJwjq2cdRf6lkX6H2yWCSEmJO2mo3Z6Mh7hRqAAYS9luyBjnu07pwOTiSxjm2Mzyn4UkNQzI7KhpSBFekKl6hxfV0YWyExhiiRkRCnfKQDFnWaqnBVqZPNBU1ItEOeL4ixSCEtT37EYKELp534WA7LRNPF2z3Mkc1Eal-zrBinlJF661SFvJLW9f-exAW1BzyfRQ7Cgkgt2nDB77M5IurA_zA-qi3WOyuB1QOU25CRVmW5iYQbGfFrBT-aTdJAUrbgJ5p-cHzE0bZyG_DV5To/file?dl=1
# Reusing existing connection to uc52d79f4a55d545a2d5c7e4823a.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 310634489 (296M) [application/binary]
# Saving to: ‘smoothed_cartoons.zip’
#
# smoothed_cartoons.z 100%[===================>] 296.24M   103MB/s    in 2.9s
#
# 2024-10-30 22:39:33 (103 MB/s) - ‘smoothed_cartoons.zip’ saved [310634489/310634489]
#
# --2024-10-30 22:39:33--  https://www.dropbox.com/scl/fi/65qw0mx7ouban34x0wxht/photos.zip?rlkey=itpjmp4x2zcaz5gwy9ljqafew&st=rgxgzzwr&dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.6.18, 2620:100:6019:18::a27d:412
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.6.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc8f4f0a3aa99827287f42024470.dl.dropboxusercontent.com/cd/0/inline/Cdc6cBas67cxR1uat6Syo_nT8DzXVz_TK4RwODfArZbjPL_HKBptzdkb2Tmw-FS6AROtyD9pl8N-gQR5GDdfMTuF30vX8LBppvsEUMJsumbF0amaVEVSgZhWjZ7DYi-rk4QzNd2mMvj7rtcboIzwdGlH/file?dl=1# [following]
# --2024-10-30 22:39:34--  https://uc8f4f0a3aa99827287f42024470.dl.dropboxusercontent.com/cd/0/inline/Cdc6cBas67cxR1uat6Syo_nT8DzXVz_TK4RwODfArZbjPL_HKBptzdkb2Tmw-FS6AROtyD9pl8N-gQR5GDdfMTuF30vX8LBppvsEUMJsumbF0amaVEVSgZhWjZ7DYi-rk4QzNd2mMvj7rtcboIzwdGlH/file?dl=1
# Resolving uc8f4f0a3aa99827287f42024470.dl.dropboxusercontent.com (uc8f4f0a3aa99827287f42024470.dl.dropboxusercontent.com)... 162.125.4.15, 2620:100:6019:15::a27d:40f
# Connecting to uc8f4f0a3aa99827287f42024470.dl.dropboxusercontent.com (uc8f4f0a3aa99827287f42024470.dl.dropboxusercontent.com)|162.125.4.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/Cddd36riKGqa_ae-G3nbK3mQf5CFhMi7i23aoiVzCwPF6C0vMGeXutudIB3oK5tvhgz839RDCpBfID1zfIZMymapS-hbeXFtVc_1VFEOBi8w0BufkB3mASUCnX238hYYfr-2zJTSoko_e-7r2TnlXyt5j8eUXNrRbnKCFWPk9LjDPR2cXQylBQ4luK-GHUNSs_Vug76x07cy2aHAxSOOF9ZTVkDG-3jrQmcJgDK_pOOXFzK8lkJlIWo_z3h83CzQaeSd-mJgDdjDxZzfL6wXZ6a4L9_0b6n8Ykaia1F1yzLi4xs2DhqCxjDo_8jjzqx6t9TZWOMbHlpAq2UsZwMFFJVFb09lLRNbt5iOT9V1jFbokmxBDuuzI4cik2ufPrY4cuk/file?dl=1 [following]
# --2024-10-30 22:39:34--  https://uc8f4f0a3aa99827287f42024470.dl.dropboxusercontent.com/cd/0/inline2/Cddd36riKGqa_ae-G3nbK3mQf5CFhMi7i23aoiVzCwPF6C0vMGeXutudIB3oK5tvhgz839RDCpBfID1zfIZMymapS-hbeXFtVc_1VFEOBi8w0BufkB3mASUCnX238hYYfr-2zJTSoko_e-7r2TnlXyt5j8eUXNrRbnKCFWPk9LjDPR2cXQylBQ4luK-GHUNSs_Vug76x07cy2aHAxSOOF9ZTVkDG-3jrQmcJgDK_pOOXFzK8lkJlIWo_z3h83CzQaeSd-mJgDdjDxZzfL6wXZ6a4L9_0b6n8Ykaia1F1yzLi4xs2DhqCxjDo_8jjzqx6t9TZWOMbHlpAq2UsZwMFFJVFb09lLRNbt5iOT9V1jFbokmxBDuuzI4cik2ufPrY4cuk/file?dl=1
# Reusing existing connection to uc8f4f0a3aa99827287f42024470.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 252988799 (241M) [application/binary]
# Saving to: ‘photos.zip’
#
# photos.zip          100%[===================>] 241.27M  45.4MB/s    in 5.5s
#
# 2024-10-30 22:39:41 (43.8 MB/s) - ‘photos.zip’ saved [252988799/252988799]
#
# --2024-10-30 22:39:41--  https://www.dropbox.com/scl/fi/pcjnxskeju656k6kmkgtx/cartoons.zip?rlkey=iq2gpqy0q2dvpi8u3htfvyo97&st=byr3wr59&dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.6.18, 2620:100:6019:18::a27d:412
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.6.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc464a46893a342eeecc2a475b34.dl.dropboxusercontent.com/cd/0/inline/Cdf_3xohVatxMme4Ue6HxwseAO-ZGMsOuctDu3I0v_nw0VIth_uL6m-mnGLpanZqqob0ed6MwHDs7eWPrI8dssLi8p6CEhgKsnwCd1dgM-Uyans4a3VHkt6KqLAQ7oALhzQoj1WzcsVEB5I8xU_8Ga95/file?dl=1# [following]
# --2024-10-30 22:39:42--  https://uc464a46893a342eeecc2a475b34.dl.dropboxusercontent.com/cd/0/inline/Cdf_3xohVatxMme4Ue6HxwseAO-ZGMsOuctDu3I0v_nw0VIth_uL6m-mnGLpanZqqob0ed6MwHDs7eWPrI8dssLi8p6CEhgKsnwCd1dgM-Uyans4a3VHkt6KqLAQ7oALhzQoj1WzcsVEB5I8xU_8Ga95/file?dl=1
# Resolving uc464a46893a342eeecc2a475b34.dl.dropboxusercontent.com (uc464a46893a342eeecc2a475b34.dl.dropboxusercontent.com)... 162.125.71.15, 2620:100:6019:15::a27d:40f
# Connecting to uc464a46893a342eeecc2a475b34.dl.dropboxusercontent.com (uc464a46893a342eeecc2a475b34.dl.dropboxusercontent.com)|162.125.71.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CddBKCmQQmRBVZwkYVmOUQqU7mvChMg0NOl001gD4ICGx5JRxXCkij-MLbtuOVPbmz4OqJZ94kx1rJnJe9gx4Zt4kKUSunONk66Xz2xNOyRhVT5pYUyDFn1mOqS-Rc5Q2k2RHKVux-4-hPT3AzhDoYtgdFPSnFXO6a_9NoLaSgSLCLKGcR9ouNSqvVLrqOs_rM6CQ0INj8Y73dhOl7Kh1jpSd8mNAMERxVD2ZvSCjvvsESAlnAm8EBeAPh_PNDz8nKY53rMBhrIlRcv_XkhCYfwrab_aeeJFTfz8k8jSEKqlM-g8uGowPUTMUMruLhcCkXz9SWG7sPTTS218wxrHH5SvPbjdyRMrf28RzpEfXrrp2yBLcoRH79wpy9m4bFADi0A/file?dl=1 [following]
# --2024-10-30 22:39:43--  https://uc464a46893a342eeecc2a475b34.dl.dropboxusercontent.com/cd/0/inline2/CddBKCmQQmRBVZwkYVmOUQqU7mvChMg0NOl001gD4ICGx5JRxXCkij-MLbtuOVPbmz4OqJZ94kx1rJnJe9gx4Zt4kKUSunONk66Xz2xNOyRhVT5pYUyDFn1mOqS-Rc5Q2k2RHKVux-4-hPT3AzhDoYtgdFPSnFXO6a_9NoLaSgSLCLKGcR9ouNSqvVLrqOs_rM6CQ0INj8Y73dhOl7Kh1jpSd8mNAMERxVD2ZvSCjvvsESAlnAm8EBeAPh_PNDz8nKY53rMBhrIlRcv_XkhCYfwrab_aeeJFTfz8k8jSEKqlM-g8uGowPUTMUMruLhcCkXz9SWG7sPTTS218wxrHH5SvPbjdyRMrf28RzpEfXrrp2yBLcoRH79wpy9m4bFADi0A/file?dl=1
# Reusing existing connection to uc464a46893a342eeecc2a475b34.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 978544890 (933M) [application/binary]
# Saving to: ‘cartoons.zip’
#
# cartoons.zip        100%[===================>] 933.21M  19.7MB/s    in 44s
#
# 2024-10-30 22:40:28 (21.4 MB/s) - ‘cartoons.zip’ saved [978544890/978544890]

# %%
# !unzip cartoons.zip -d cartoons
# !unzip smoothed_cartoons.zip -d smoothed_cartoons
# !unzip coco.zip -x "__MACOSX/*" "*.DS_Store"
# Out:
# Archive:  cartoons.zip
# replace cartoons/cartoons1/cartoons/sample_f55b80a8b7da36b5d179f32cb2fac5be71a26ea0.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: Archive:  smoothed_cartoons.zip
# replace smoothed_cartoons/cartoons_smoothed/safebooru_smoothed/sample_f55b80a8b7da36b5d179f32cb2fac5be71a26ea0.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: Archive:  coco.zip
# replace coco_images/coco/000000267625.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# !wget -O cocoimg.zip "https://www.dropbox.com/scl/fi/oh0lsqhlf6kdbcrglhewf/coco_images.zip?rlkey=ltrlb1fnemfxhvixzcsnbbbaf&st=3vf59pp4&dl=1"
# Out:
# --2024-10-30 23:09:29--  https://www.dropbox.com/scl/fi/oh0lsqhlf6kdbcrglhewf/coco_images.zip?rlkey=ltrlb1fnemfxhvixzcsnbbbaf&st=3vf59pp4&dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.4.18, 2620:100:6019:18::a27d:412
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.4.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucbfab4e5850aafa0c2fd2053572.dl.dropboxusercontent.com/cd/0/inline/Cdfx1T-0OQmmpuzDORIz7GqZouDAVj6vKLWqiOYUCdSoVgvaJgiDDrwYtOtuZOgkJmsye8g795auQkBRUJPpQZBsnRmZfuLhZVxfWguYdg3dpC7jNw_bKBYlf-bevaaKy8io9v05dYd2IT-2hFDRrcGO/file?dl=1# [following]
# --2024-10-30 23:09:30--  https://ucbfab4e5850aafa0c2fd2053572.dl.dropboxusercontent.com/cd/0/inline/Cdfx1T-0OQmmpuzDORIz7GqZouDAVj6vKLWqiOYUCdSoVgvaJgiDDrwYtOtuZOgkJmsye8g795auQkBRUJPpQZBsnRmZfuLhZVxfWguYdg3dpC7jNw_bKBYlf-bevaaKy8io9v05dYd2IT-2hFDRrcGO/file?dl=1
# Resolving ucbfab4e5850aafa0c2fd2053572.dl.dropboxusercontent.com (ucbfab4e5850aafa0c2fd2053572.dl.dropboxusercontent.com)... 162.125.6.15, 2620:100:6019:15::a27d:40f
# Connecting to ucbfab4e5850aafa0c2fd2053572.dl.dropboxusercontent.com (ucbfab4e5850aafa0c2fd2053572.dl.dropboxusercontent.com)|162.125.6.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/Cdd48fYSKOu7kblMMtJUoBU33EtNtbt-0tPW2aWOsMV9i0LU552uVDW9Q68BP04Wfu98PHr7iXlx0zxJ_crGkuIPp3E1BT_8mG9JdospylUDL4GRBMaDvwDXfGyuHG1IDhMTawUhmGfM58P1d7Ce6gwBQ-E0ChPCZ_wt5XKW9-rFXTMT0196IPrAZGH3hG4vnzLb3G1o-1moNQLzycd0GeukFP5MXV-v6n8sqNzsHvPYmkKzZhag7hvutO4w9hHNV2ngsCiEiyLFoZgTBo7jG8UYDX3gJnHxX4RjgRzn6tYx2zRs1Wd6WPX_gqdXN0ZFI1SKjSI5Bg1yIndRBJi_RPQ6OUyZIhKglu0OOJ5dpR8AOI-QHeQ_7D_x1eWtdRCSO6Y/file?dl=1 [following]
# --2024-10-30 23:09:31--  https://ucbfab4e5850aafa0c2fd2053572.dl.dropboxusercontent.com/cd/0/inline2/Cdd48fYSKOu7kblMMtJUoBU33EtNtbt-0tPW2aWOsMV9i0LU552uVDW9Q68BP04Wfu98PHr7iXlx0zxJ_crGkuIPp3E1BT_8mG9JdospylUDL4GRBMaDvwDXfGyuHG1IDhMTawUhmGfM58P1d7Ce6gwBQ-E0ChPCZ_wt5XKW9-rFXTMT0196IPrAZGH3hG4vnzLb3G1o-1moNQLzycd0GeukFP5MXV-v6n8sqNzsHvPYmkKzZhag7hvutO4w9hHNV2ngsCiEiyLFoZgTBo7jG8UYDX3gJnHxX4RjgRzn6tYx2zRs1Wd6WPX_gqdXN0ZFI1SKjSI5Bg1yIndRBJi_RPQ6OUyZIhKglu0OOJ5dpR8AOI-QHeQ_7D_x1eWtdRCSO6Y/file?dl=1
# Reusing existing connection to ucbfab4e5850aafa0c2fd2053572.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 650724141 (621M) [application/binary]
# Saving to: ‘cocoimg.zip’
#
# cocoimg.zip         100%[===================>] 620.58M   115MB/s    in 5.7s
#
# 2024-10-30 23:09:36 (108 MB/s) - ‘cocoimg.zip’ saved [650724141/650724141]

# %%
# !unzip cocoimg.zip -d cocoimgs -x "__MACOSX/*" "*.DS_Store"
# Out:
# Archive:  cocoimg.zip
#    creating: cocoimgs/coco_images/
#    creating: cocoimgs/coco_images/coco/
#   inflating: cocoimgs/coco_images/coco/000000267625.jpg
#   inflating: cocoimgs/coco_images/coco/000000268516.jpg
#   inflating: cocoimgs/coco_images/coco/000000526350.jpg
#   inflating: cocoimgs/coco_images/coco/000000398183.jpg
#   inflating: cocoimgs/coco_images/coco/000000004312.jpg
#   inflating: cocoimgs/coco_images/coco/000000524547.jpg
#   inflating: cocoimgs/coco_images/coco/000000005018.jpg
#   inflating: cocoimgs/coco_images/coco/000000394975.jpg
#   inflating: cocoimgs/coco_images/coco/000000262991.jpg
#   inflating: cocoimgs/coco_images/coco/000000264338.jpg
#   inflating: cocoimgs/coco_images/coco/000000133596.jpg
#   inflating: cocoimgs/coco_images/coco/000000393954.jpg
#   inflating: cocoimgs/coco_images/coco/000000005756.jpg
#   inflating: cocoimgs/coco_images/coco/000000269152.jpg
#   inflating: cocoimgs/coco_images/coco/000000006539.jpg
#   inflating: cocoimgs/coco_images/coco/000000396186.jpg
#   inflating: cocoimgs/coco_images/coco/000000266275.jpg
#   inflating: cocoimgs/coco_images/coco/000000313198.jpg
#   inflating: cocoimgs/coco_images/coco/000000264304.jpg
#   inflating: cocoimgs/coco_images/coco/000000396838.jpg
#   inflating: cocoimgs/coco_images/coco/000000134206.jpg
#   inflating: cocoimgs/coco_images/coco/000000131418.jpg
#   inflating: cocoimgs/coco_images/coco/000000398140.jpg
#   inflating: cocoimgs/coco_images/coco/000000134574.jpg
#   inflating: cocoimgs/coco_images/coco/000000396179.jpg
#   inflating: cocoimgs/coco_images/coco/000000262952.jpg
#   inflating: cocoimgs/coco_images/coco/000000131342.jpg
#   inflating: cocoimgs/coco_images/coco/000000393997.jpg
#   inflating: cocoimgs/coco_images/coco/000000267802.jpg
#   inflating: cocoimgs/coco_images/coco/000000001295.jpg
#   inflating: cocoimgs/coco_images/coco/000000265967.jpg
#   inflating: cocoimgs/coco_images/coco/000000000821.jpg
#   inflating: cocoimgs/coco_images/coco/000000396623.jpg
#   inflating: cocoimgs/coco_images/coco/000000399510.jpg
#   inflating: cocoimgs/coco_images/coco/000000262239.jpg
#   inflating: cocoimgs/coco_images/coco/000000268072.jpg
#   inflating: cocoimgs/coco_images/coco/000000004662.jpg
#   inflating: cocoimgs/coco_images/coco/000000006075.jpg
#   inflating: cocoimgs/coco_images/coco/000000133964.jpg
#   inflating: cocoimgs/coco_images/coco/000000002575.jpg
#   inflating: cocoimgs/coco_images/coco/000000264884.jpg
#   inflating: cocoimgs/coco_images/coco/000000131815.jpg
#   inflating: cocoimgs/coco_images/coco/000000527270.jpg
#   inflating: cocoimgs/coco_images/coco/000000135483.jpg
#   inflating: cocoimgs/coco_images/coco/000000525467.jpg
#   inflating: cocoimgs/coco_images/coco/000000003125.jpg
#   inflating: cocoimgs/coco_images/coco/000000001732.jpg
#   inflating: cocoimgs/coco_images/coco/000000526608.jpg
#   inflating: cocoimgs/coco_images/coco/000000269422.jpg
#   inflating: cocoimgs/coco_images/coco/000000007357.jpg
#   inflating: cocoimgs/coco_images/coco/000000136820.jpg
#   inflating: cocoimgs/coco_images/coco/000000131197.jpg
#   inflating: cocoimgs/coco_images/coco/000000004138.jpg
#   inflating: cocoimgs/coco_images/coco/000000264660.jpg
#   inflating: cocoimgs/coco_images/coco/000000528157.jpg
#   inflating: cocoimgs/coco_images/coco/000000527264.jpg
#   inflating: cocoimgs/coco_images/coco/000000135497.jpg
#   inflating: cocoimgs/coco_images/coco/000000524786.jpg
#   inflating: cocoimgs/coco_images/coco/000000264853.jpg
#   inflating: cocoimgs/coco_images/coco/000000001915.jpg
#   inflating: cocoimgs/coco_images/coco/000000266922.jpg
#   inflating: cocoimgs/coco_images/coco/000000134010.jpg
#   inflating: cocoimgs/coco_images/coco/000000262588.jpg
#   inflating: cocoimgs/coco_images/coco/000000263696.jpg
#   inflating: cocoimgs/coco_images/coco/000000003870.jpg
#   inflating: cocoimgs/coco_images/coco/000000132307.jpg
#   inflating: cocoimgs/coco_images/coco/000000524962.jpg
#   inflating: cocoimgs/coco_images/coco/000000134986.jpg
#   inflating: cocoimgs/coco_images/coco/000000000389.jpg
#   inflating: cocoimgs/coco_images/coco/000000006920.jpg
#   inflating: cocoimgs/coco_images/coco/000000135326.jpg
#   inflating: cocoimgs/coco_images/coco/000000007394.jpg
#   inflating: cocoimgs/coco_images/coco/000000268927.jpg
#   inflating: cocoimgs/coco_images/coco/000000530903.jpg
#   inflating: cocoimgs/coco_images/coco/000000133025.jpg
#   inflating: cocoimgs/coco_images/coco/000000003694.jpg
#   inflating: cocoimgs/coco_images/coco/000000002415.jpg
#   inflating: cocoimgs/coco_images/coco/000000000564.jpg
#   inflating: cocoimgs/coco_images/coco/000000525249.jpg
#   inflating: cocoimgs/coco_images/coco/000000004702.jpg
#   inflating: cocoimgs/coco_images/coco/000000004716.jpg
#   inflating: cocoimgs/coco_images/coco/000000399841.jpg
#   inflating: cocoimgs/coco_images/coco/000000006101.jpg
#   inflating: cocoimgs/coco_images/coco/000000266659.jpg
#   inflating: cocoimgs/coco_images/coco/000000134819.jpg
#   inflating: cocoimgs/coco_images/coco/000000001108.jpg
#   inflating: cocoimgs/coco_images/coco/000000530650.jpg
#   inflating: cocoimgs/coco_images/coco/000000131961.jpg
#   inflating: cocoimgs/coco_images/coco/000000262359.jpg
#   inflating: cocoimgs/coco_images/coco/000000132298.jpg
#   inflating: cocoimgs/coco_images/coco/000000525513.jpg
#   inflating: cocoimgs/coco_images/coco/000000527476.jpg
#   inflating: cocoimgs/coco_images/coco/000000396596.jpg
#   inflating: cocoimgs/coco_images/coco/000000134825.jpg
#   inflating: cocoimgs/coco_images/coco/000000397105.jpg
#   inflating: cocoimgs/coco_images/coco/000000135508.jpg
#   inflating: cocoimgs/coco_images/coco/000000137479.jpg
#   inflating: cocoimgs/coco_images/coco/000000528962.jpg
#   inflating: cocoimgs/coco_images/coco/000000132515.jpg
#   inflating: cocoimgs/coco_images/coco/000000398544.jpg
#   inflating: cocoimgs/coco_images/coco/000000001875.jpg
#   inflating: cocoimgs/coco_images/coco/000000393411.jpg
#   inflating: cocoimgs/coco_images/coco/000000136015.jpg
#   inflating: cocoimgs/coco_images/coco/000000394418.jpg
#   inflating: cocoimgs/coco_images/coco/000000263084.jpg
#   inflating: cocoimgs/coco_images/coco/000000398222.jpg
#   inflating: cocoimgs/coco_images/coco/000000005385.jpg
#   inflating: cocoimgs/coco_images/coco/000000133145.jpg
#   inflating: cocoimgs/coco_images/coco/000000396541.jpg
#   inflating: cocoimgs/coco_images/coco/000000137451.jpg
#   inflating: cocoimgs/coco_images/coco/000000397893.jpg
#   inflating: cocoimgs/coco_images/coco/000000399666.jpg
#   inflating: cocoimgs/coco_images/coco/000000132529.jpg
#   inflating: cocoimgs/coco_images/coco/000000528786.jpg
#   inflating: cocoimgs/coco_images/coco/000000003938.jpg
#   inflating: cocoimgs/coco_images/coco/000000524802.jpg
#   inflating: cocoimgs/coco_images/coco/000000002171.jpg
#   inflating: cocoimgs/coco_images/coco/000000398949.jpg
#   inflating: cocoimgs/coco_images/coco/000000526542.jpg
#   inflating: cocoimgs/coco_images/coco/000000005178.jpg
#   inflating: cocoimgs/coco_images/coco/000000004266.jpg
#   inflating: cocoimgs/coco_images/coco/000000263251.jpg
#   inflating: cocoimgs/coco_images/coco/000000006465.jpg
#   inflating: cocoimgs/coco_images/coco/000000529665.jpg
#   inflating: cocoimgs/coco_images/coco/000000396780.jpg
#   inflating: cocoimgs/coco_images/coco/000000396958.jpg
#   inflating: cocoimgs/coco_images/coco/000000007035.jpg
#   inflating: cocoimgs/coco_images/coco/000000394197.jpg
#   inflating: cocoimgs/coco_images/coco/000000395289.jpg
#   inflating: cocoimgs/coco_images/coco/000000131593.jpg
#   inflating: cocoimgs/coco_images/coco/000000264502.jpg
#   inflating: cocoimgs/coco_images/coco/000000003535.jpg
#   inflating: cocoimgs/coco_images/coco/000000133384.jpg
#   inflating: cocoimgs/coco_images/coco/000000527112.jpg
#   inflating: cocoimgs/coco_images/coco/000000525705.jpg
#   inflating: cocoimgs/coco_images/coco/000000003521.jpg
#   inflating: cocoimgs/coco_images/coco/000000137690.jpg
#   inflating: cocoimgs/coco_images/coco/000000531016.jpg
#   inflating: cocoimgs/coco_images/coco/000000267779.jpg
#   inflating: cocoimgs/coco_images/coco/000000398752.jpg
#   inflating: cocoimgs/coco_images/coco/000000397461.jpg
#   inflating: cocoimgs/coco_images/coco/000000136565.jpg
#   inflating: cocoimgs/coco_images/coco/000000263292.jpg
#   inflating: cocoimgs/coco_images/coco/000000395504.jpg
#   inflating: cocoimgs/coco_images/coco/000000005811.jpg
#   inflating: cocoimgs/coco_images/coco/000000134366.jpg
#   inflating: cocoimgs/coco_images/coco/000000398746.jpg
#   inflating: cocoimgs/coco_images/coco/000000397475.jpg
#   inflating: cocoimgs/coco_images/coco/000000000969.jpg
#   inflating: cocoimgs/coco_images/coco/000000396030.jpg
#   inflating: cocoimgs/coco_images/coco/000000394627.jpg
#   inflating: cocoimgs/coco_images/coco/000000137134.jpg
#   inflating: cocoimgs/coco_images/coco/000000135045.jpg
#   inflating: cocoimgs/coco_images/coco/000000399465.jpg
#   inflating: cocoimgs/coco_images/coco/000000529857.jpg
#   inflating: cocoimgs/coco_images/coco/000000137120.jpg
#   inflating: cocoimgs/coco_images/coco/000000399317.jpg
#   inflating: cocoimgs/coco_images/coco/000000137108.jpg
#   inflating: cocoimgs/coco_images/coco/000000136570.jpg
#   inflating: cocoimgs/coco_images/coco/000000265184.jpg
#   inflating: cocoimgs/coco_images/coco/000000526580.jpg
#   inflating: cocoimgs/coco_images/coco/000000398753.jpg
#   inflating: cocoimgs/coco_images/coco/000000136202.jpg
#   inflating: cocoimgs/coco_images/coco/000000263278.jpg
#   inflating: cocoimgs/coco_images/coco/000000269033.jpg
#   inflating: cocoimgs/coco_images/coco/000000135938.jpg
#   inflating: cocoimgs/coco_images/coco/000000001451.jpg
#   inflating: cocoimgs/coco_images/coco/000000137849.jpg
#   inflating: cocoimgs/coco_images/coco/000000529102.jpg
#   inflating: cocoimgs/coco_images/coco/000000267022.jpg
#   inflating: cocoimgs/coco_images/coco/000000265635.jpg
#   inflating: cocoimgs/coco_images/coco/000000002602.jpg
#   inflating: cocoimgs/coco_images/coco/000000265153.jpg
#   inflating: cocoimgs/coco_images/coco/000000393809.jpg
#   inflating: cocoimgs/coco_images/coco/000000527649.jpg
#   inflating: cocoimgs/coco_images/coco/000000529670.jpg
#   inflating: cocoimgs/coco_images/coco/000000003939.jpg
#   inflating: cocoimgs/coco_images/coco/000000530876.jpg
#   inflating: cocoimgs/coco_images/coco/000000399101.jpg
#   inflating: cocoimgs/coco_images/coco/000000393438.jpg
#   inflating: cocoimgs/coco_images/coco/000000134165.jpg
#   inflating: cocoimgs/coco_images/coco/000000132272.jpg
#   inflating: cocoimgs/coco_images/coco/000000136014.jpg
#   inflating: cocoimgs/coco_images/coco/000000003911.jpg
#   inflating: cocoimgs/coco_images/coco/000000264926.jpg
#   inflating: cocoimgs/coco_images/coco/000000399129.jpg
#   inflating: cocoimgs/coco_images/coco/000000397104.jpg
#   inflating: cocoimgs/coco_images/coco/000000530686.jpg
#   inflating: cocoimgs/coco_images/coco/000000132500.jpg
#   inflating: cocoimgs/coco_images/coco/000000526769.jpg
#   inflating: cocoimgs/coco_images/coco/000000527477.jpg
#   inflating: cocoimgs/coco_images/coco/000000395920.jpg
#   inflating: cocoimgs/coco_images/coco/000000006896.jpg
#   inflating: cocoimgs/coco_images/coco/000000132299.jpg
#   inflating: cocoimgs/coco_images/coco/000000269543.jpg
#   inflating: cocoimgs/coco_images/coco/000000133839.jpg
#   inflating: cocoimgs/coco_images/coco/000000531201.jpg
#   inflating: cocoimgs/coco_images/coco/000000399868.jpg
#   inflating: cocoimgs/coco_images/coco/000000266880.jpg
#   inflating: cocoimgs/coco_images/coco/000000265351.jpg
#   inflating: cocoimgs/coco_images/coco/000000002400.jpg
#   inflating: cocoimgs/coco_images/coco/000000529300.jpg
#   inflating: cocoimgs/coco_images/coco/000000526033.jpg
#   inflating: cocoimgs/coco_images/coco/000000134818.jpg
#   inflating: cocoimgs/coco_images/coco/000000530645.jpg
#   inflating: cocoimgs/coco_images/coco/000000529314.jpg
#   inflating: cocoimgs/coco_images/coco/000000263052.jpg
#   inflating: cocoimgs/coco_images/coco/000000004065.jpg
#   inflating: cocoimgs/coco_images/coco/000000263734.jpg
#   inflating: cocoimgs/coco_images/coco/000000002372.jpg
#   inflating: cocoimgs/coco_images/coco/000000263873.jpg
#   inflating: cocoimgs/coco_images/coco/000000004844.jpg
#   inflating: cocoimgs/coco_images/coco/000000006935.jpg
#   inflating: cocoimgs/coco_images/coco/000000397058.jpg
#   inflating: cocoimgs/coco_images/coco/000000006921.jpg
#   inflating: cocoimgs/coco_images/coco/000000137256.jpg
#   inflating: cocoimgs/coco_images/coco/000000004688.jpg
#   inflating: cocoimgs/coco_images/coco/000000135327.jpg
#   inflating: cocoimgs/coco_images/coco/000000134039.jpg
#   inflating: cocoimgs/coco_images/coco/000000001900.jpg
#   inflating: cocoimgs/coco_images/coco/000000397064.jpg
#   inflating: cocoimgs/coco_images/coco/000000399049.jpg
#   inflating: cocoimgs/coco_images/coco/000000264846.jpg
#   inflating: cocoimgs/coco_images/coco/000000395673.jpg
#   inflating: cocoimgs/coco_images/coco/000000003865.jpg
#   inflating: cocoimgs/coco_images/coco/000000265594.jpg
#   inflating: cocoimgs/coco_images/coco/000000397716.jpg
#   inflating: cocoimgs/coco_images/coco/000000395101.jpg
#   inflating: cocoimgs/coco_images/coco/000000263668.jpg
#   inflating: cocoimgs/coco_images/coco/000000396385.jpg
#   inflating: cocoimgs/coco_images/coco/000000529248.jpg
#   inflating: cocoimgs/coco_images/coco/000000530719.jpg
#   inflating: cocoimgs/coco_images/coco/000000004139.jpg
#   inflating: cocoimgs/coco_images/coco/000000395840.jpg
#   inflating: cocoimgs/coco_images/coco/000000528142.jpg
#   inflating: cocoimgs/coco_images/coco/000000528624.jpg
#   inflating: cocoimgs/coco_images/coco/000000004893.jpg
#   inflating: cocoimgs/coco_images/coco/000000525300.jpg
#   inflating: cocoimgs/coco_images/coco/000000003124.jpg
#   inflating: cocoimgs/coco_images/coco/000000006074.jpg
#   inflating: cocoimgs/coco_images/coco/000000006712.jpg
#   inflating: cocoimgs/coco_images/coco/000000529260.jpg
#   inflating: cocoimgs/coco_images/coco/000000530731.jpg
#   inflating: cocoimgs/coco_images/coco/000000131800.jpg
#   inflating: cocoimgs/coco_images/coco/000000262238.jpg
#   inflating: cocoimgs/coco_images/coco/000000002560.jpg
#   inflating: cocoimgs/coco_images/coco/000000005569.jpg
#   inflating: cocoimgs/coco_images/coco/000000003118.jpg
#   inflating: cocoimgs/coco_images/coco/000000002951.jpg
#   inflating: cocoimgs/coco_images/coco/000000133540.jpg
#   inflating: cocoimgs/coco_images/coco/000000396636.jpg
#   inflating: cocoimgs/coco_images/coco/000000131343.jpg
#   inflating: cocoimgs/coco_images/coco/000000138401.jpg
#   inflating: cocoimgs/coco_images/coco/000000394747.jpg
#   inflating: cocoimgs/coco_images/coco/000000396150.jpg
#   inflating: cocoimgs/coco_images/coco/000000134575.jpg
#   inflating: cocoimgs/coco_images/coco/000000530282.jpg
#   inflating: cocoimgs/coco_images/coco/000000397500.jpg
#   inflating: cocoimgs/coco_images/coco/000000397514.jpg
#   inflating: cocoimgs/coco_images/coco/000000131419.jpg
#   inflating: cocoimgs/coco_images/coco/000000265796.jpg
#   inflating: cocoimgs/coco_images/coco/000000002992.jpg
#   inflating: cocoimgs/coco_images/coco/000000394790.jpg
#   inflating: cocoimgs/coco_images/coco/000000531163.jpg
#   inflating: cocoimgs/coco_images/coco/000000003326.jpg
#   inflating: cocoimgs/coco_images/coco/000000000149.jpg
#   inflating: cocoimgs/coco_images/coco/000000527073.jpg
#   inflating: cocoimgs/coco_images/coco/000000394784.jpg
#   inflating: cocoimgs/coco_images/coco/000000399288.jpg
#   inflating: cocoimgs/coco_images/coco/000000006262.jpg
#   inflating: cocoimgs/coco_images/coco/000000525880.jpg
#   inflating: cocoimgs/coco_images/coco/000000002774.jpg
#   inflating: cocoimgs/coco_images/coco/000000526347.jpg
#   inflating: cocoimgs/coco_images/coco/000000526353.jpg
#   inflating: cocoimgs/coco_images/coco/000000400380.jpg
#   inflating: cocoimgs/coco_images/coco/000000005769.jpg
#   inflating: cocoimgs/coco_images/coco/000000263440.jpg
#   inflating: cocoimgs/coco_images/coco/000000531149.jpg
#   inflating: cocoimgs/coco_images/coco/000000393943.jpg
#   inflating: cocoimgs/coco_images/coco/000000264307.jpg
#   inflating: cocoimgs/coco_images/coco/000000001527.jpg
#   inflating: cocoimgs/coco_images/coco/000000005033.jpg
#   inflating: cocoimgs/coco_images/coco/000000525666.jpg
#   inflating: cocoimgs/coco_images/coco/000000395498.jpg
#   inflating: cocoimgs/coco_images/coco/000000525100.jpg
#   inflating: cocoimgs/coco_images/coco/000000400431.jpg
#   inflating: cocoimgs/coco_images/coco/000000262951.jpg
#   inflating: cocoimgs/coco_images/coco/000000134211.jpg
#   inflating: cocoimgs/coco_images/coco/000000209128.jpg
#   inflating: cocoimgs/coco_images/coco/000000266289.jpg
#   inflating: cocoimgs/coco_images/coco/000000395473.jpg
#   inflating: cocoimgs/coco_images/coco/000000525841.jpg
#   inflating: cocoimgs/coco_images/coco/000000400343.jpg
#   inflating: cocoimgs/coco_images/coco/000000530294.jpg
#   inflating: cocoimgs/coco_images/coco/000000267815.jpg
#   inflating: cocoimgs/coco_images/coco/000000137724.jpg
#   inflating: cocoimgs/coco_images/coco/000000137042.jpg
#   inflating: cocoimgs/coco_images/coco/000000265964.jpg
#   inflating: cocoimgs/coco_images/coco/000000131427.jpg
#   inflating: cocoimgs/coco_images/coco/000000000836.jpg
#   inflating: cocoimgs/coco_images/coco/000000133556.jpg
#   inflating: cocoimgs/coco_images/coco/000000268065.jpg
#   inflating: cocoimgs/coco_images/coco/000000006710.jpg
#   inflating: cocoimgs/coco_images/coco/000000005219.jpg
#   inflating: cocoimgs/coco_images/coco/000000131816.jpg
#   inflating: cocoimgs/coco_images/coco/000000265227.jpg
#   inflating: cocoimgs/coco_images/coco/000000399922.jpg
#   inflating: cocoimgs/coco_images/coco/000000268717.jpg
#   inflating: cocoimgs/coco_images/coco/000000002562.jpg
#   inflating: cocoimgs/coco_images/coco/000000398382.jpg
#   inflating: cocoimgs/coco_images/coco/000000005225.jpg
#   inflating: cocoimgs/coco_images/coco/000000394590.jpg
#   inflating: cocoimgs/coco_images/coco/000000268059.jpg
#   inflating: cocoimgs/coco_images/coco/000000527267.jpg
#   inflating: cocoimgs/coco_images/coco/000000004891.jpg
#   inflating: cocoimgs/coco_images/coco/000000530069.jpg
#   inflating: cocoimgs/coco_images/coco/000000135480.jpg
#   inflating: cocoimgs/coco_images/coco/000000137297.jpg
#   inflating: cocoimgs/coco_images/coco/000000526186.jpg
#   inflating: cocoimgs/coco_images/coco/000000530082.jpg
#   inflating: cocoimgs/coco_images/coco/000000398433.jpg
#   inflating: cocoimgs/coco_images/coco/000000268918.jpg
#   inflating: cocoimgs/coco_images/coco/000000394209.jpg
#   inflating: cocoimgs/coco_images/coco/000000134007.jpg
#   inflating: cocoimgs/coco_images/coco/000000132476.jpg
#   inflating: cocoimgs/coco_images/coco/000000132310.jpg
#   inflating: cocoimgs/coco_images/coco/000000395665.jpg
#   inflating: cocoimgs/coco_images/coco/000000528197.jpg
#   inflating: cocoimgs/coco_images/coco/000000526810.jpg
#   inflating: cocoimgs/coco_images/coco/000000394547.jpg
#   inflating: cocoimgs/coco_images/coco/000000396350.jpg
#   inflating: cocoimgs/coco_images/coco/000000006664.jpg
#   inflating: cocoimgs/coco_images/coco/000000530653.jpg
#   inflating: cocoimgs/coco_images/coco/000000002402.jpg
#   inflating: cocoimgs/coco_images/coco/000000265353.jpg
#   inflating: cocoimgs/coco_images/coco/000000529470.jpg
#   inflating: cocoimgs/coco_images/coco/000000131976.jpg
#   inflating: cocoimgs/coco_images/coco/000000000201.jpg
#   inflating: cocoimgs/coco_images/coco/000000268105.jpg
#   inflating: cocoimgs/coco_images/coco/000000006658.jpg
#   inflating: cocoimgs/coco_images/coco/000000527313.jpg
#   inflating: cocoimgs/coco_images/coco/000000528020.jpg
#   inflating: cocoimgs/coco_images/coco/000000134198.jpg
#   inflating: cocoimgs/coco_images/coco/000000137491.jpg
#   inflating: cocoimgs/coco_images/coco/000000262414.jpg
#   inflating: cocoimgs/coco_images/coco/000000136943.jpg
#   inflating: cocoimgs/coco_images/coco/000000135292.jpg
#   inflating: cocoimgs/coco_images/coco/000000269541.jpg
#   inflating: cocoimgs/coco_images/coco/000000134832.jpg
#   inflating: cocoimgs/coco_images/coco/000000266114.jpg
#   inflating: cocoimgs/coco_images/coco/000000525510.jpg
#   inflating: cocoimgs/coco_images/coco/000000262399.jpg
#   inflating: cocoimgs/coco_images/coco/000000264930.jpg
#   inflating: cocoimgs/coco_images/coco/000000530690.jpg
#   inflating: cocoimgs/coco_images/coco/000000528961.jpg
#   inflating: cocoimgs/coco_images/coco/000000132516.jpg
#   inflating: cocoimgs/coco_images/coco/000000133608.jpg
#   inflating: cocoimgs/coco_images/coco/000000399881.jpg
#   inflating: cocoimgs/coco_images/coco/000000136770.jpg
#   inflating: cocoimgs/coco_images/coco/000000136764.jpg
#   inflating: cocoimgs/coco_images/coco/000000526958.jpg
#   inflating: cocoimgs/coco_images/coco/000000397890.jpg
#   inflating: cocoimgs/coco_images/coco/000000396556.jpg
#   inflating: cocoimgs/coco_images/coco/000000397648.jpg
#   inflating: cocoimgs/coco_images/coco/000000133634.jpg
#   inflating: cocoimgs/coco_images/coco/000000396542.jpg
#   inflating: cocoimgs/coco_images/coco/000000133620.jpg
#   inflating: cocoimgs/coco_images/coco/000000003091.jpg
#   inflating: cocoimgs/coco_images/coco/000000132258.jpg
#   inflating: cocoimgs/coco_images/coco/000000526555.jpg
#   inflating: cocoimgs/coco_images/coco/000000530337.jpg
#   inflating: cocoimgs/coco_images/coco/000000265151.jpg
#   inflating: cocoimgs/coco_images/coco/000000137877.jpg
#   inflating: cocoimgs/coco_images/coco/000000268313.jpg
#   inflating: cocoimgs/coco_images/coco/000000002614.jpg
#   inflating: cocoimgs/coco_images/coco/000000265145.jpg
#   inflating: cocoimgs/coco_images/coco/000000527887.jpg
#   inflating: cocoimgs/coco_images/coco/000000393837.jpg
#   inflating: cocoimgs/coco_images/coco/000000001453.jpg
#   inflating: cocoimgs/coco_images/coco/000000004259.jpg
#   inflating: cocoimgs/coco_images/coco/000000132099.jpg
#   inflating: cocoimgs/coco_images/coco/000000396768.jpg
#   inflating: cocoimgs/coco_images/coco/000000136200.jpg
#   inflating: cocoimgs/coco_images/coco/000000530486.jpg
#   inflating: cocoimgs/coco_images/coco/000000397462.jpg
#   inflating: cocoimgs/coco_images/coco/000000527844.jpg
#   inflating: cocoimgs/coco_images/coco/000000265186.jpg
#   inflating: cocoimgs/coco_images/coco/000000528587.jpg
#   inflating: cocoimgs/coco_images/coco/000000133436.jpg
#   inflating: cocoimgs/coco_images/coco/000000396754.jpg
#   inflating: cocoimgs/coco_images/coco/000000137888.jpg
#   inflating: cocoimgs/coco_images/coco/000000265810.jpg
#   inflating: cocoimgs/coco_images/coco/000000135735.jpg
#   inflating: cocoimgs/coco_images/coco/000000002833.jpg
#   inflating: cocoimgs/coco_images/coco/000000003293.jpg
#   inflating: cocoimgs/coco_images/coco/000000525908.jpg
#   inflating: cocoimgs/coco_images/coco/000000000943.jpg
#   inflating: cocoimgs/coco_images/coco/000000396741.jpg
#   inflating: cocoimgs/coco_images/coco/000000395248.jpg
#   inflating: cocoimgs/coco_images/coco/000000529698.jpg
#   inflating: cocoimgs/coco_images/coco/000000136229.jpg
#   inflating: cocoimgs/coco_images/coco/000000398036.jpg
#   inflating: cocoimgs/coco_images/coco/000000132067.jpg
#   inflating: cocoimgs/coco_images/coco/000000131208.jpg
#   inflating: cocoimgs/coco_images/coco/000000265187.jpg
#   inflating: cocoimgs/coco_images/coco/000000526597.jpg
#   inflating: cocoimgs/coco_images/coco/000000398744.jpg
#   inflating: cocoimgs/coco_images/coco/000000400544.jpg
#   inflating: cocoimgs/coco_images/coco/000000133386.jpg
#   inflating: cocoimgs/coco_images/coco/000000262171.jpg
#   inflating: cocoimgs/coco_images/coco/000000525075.jpg
#   inflating: cocoimgs/coco_images/coco/000000262617.jpg
#   inflating: cocoimgs/coco_images/coco/000000005620.jpg
#   inflating: cocoimgs/coco_images/coco/000000007023.jpg
#   inflating: cocoimgs/coco_images/coco/000000526568.jpg
#   inflating: cocoimgs/coco_images/coco/000000531014.jpg
#   inflating: cocoimgs/coco_images/coco/000000262603.jpg
#   inflating: cocoimgs/coco_images/coco/000000264514.jpg
#   inflating: cocoimgs/coco_images/coco/000000005152.jpg
#   inflating: cocoimgs/coco_images/coco/000000524431.jpg
#   inflating: cocoimgs/coco_images/coco/000000265622.jpg
#   inflating: cocoimgs/coco_images/coco/000000268306.jpg
#   inflating: cocoimgs/coco_images/coco/000000000764.jpg
#   inflating: cocoimgs/coco_images/coco/000000267753.jpg
#   inflating: cocoimgs/coco_images/coco/000000396966.jpg
#   inflating: cocoimgs/coco_images/coco/000000527886.jpg
#   inflating: cocoimgs/coco_images/coco/000000004502.jpg
#   inflating: cocoimgs/coco_images/coco/000000005608.jpg
#   inflating: cocoimgs/coco_images/coco/000000396972.jpg
#   inflating: cocoimgs/coco_images/coco/000000529667.jpg
#   inflating: cocoimgs/coco_images/coco/000000526554.jpg
#   inflating: cocoimgs/coco_images/coco/000000399499.jpg
#   inflating: cocoimgs/coco_images/coco/000000001308.jpg
#   inflating: cocoimgs/coco_images/coco/000000526232.jpg
#   inflating: cocoimgs/coco_images/coco/000000135250.jpg
#   inflating: cocoimgs/coco_images/coco/000000268845.jpg
#   inflating: cocoimgs/coco_images/coco/000000264919.jpg
#   inflating: cocoimgs/coco_images/coco/000000530875.jpg
#   inflating: cocoimgs/coco_images/coco/000000135244.jpg
#   inflating: cocoimgs/coco_images/coco/000000132265.jpg
#   inflating: cocoimgs/coco_images/coco/000000393375.jpg
#   inflating: cocoimgs/coco_images/coco/000000399880.jpg
#   inflating: cocoimgs/coco_images/coco/000000528960.jpg
#   inflating: cocoimgs/coco_images/coco/000000003735.jpg
#   inflating: cocoimgs/coco_images/coco/000000135287.jpg
#   inflating: cocoimgs/coco_images/coco/000000268892.jpg
#   inflating: cocoimgs/coco_images/coco/000000001888.jpg
#   inflating: cocoimgs/coco_images/coco/000000007221.jpg
#   inflating: cocoimgs/coco_images/coco/000000004700.jpg
#   inflating: cocoimgs/coco_images/coco/000000004066.jpg
#   inflating: cocoimgs/coco_images/coco/000000525539.jpg
#   inflating: cocoimgs/coco_images/coco/000000524627.jpg
#   inflating: cocoimgs/coco_images/coco/000000530652.jpg
#   inflating: cocoimgs/coco_images/coco/000000529303.jpg
#   inflating: cocoimgs/coco_images/coco/000000133812.jpg
#   inflating: cocoimgs/coco_images/coco/000000000572.jpg
#   inflating: cocoimgs/coco_images/coco/000000004714.jpg
#   inflating: cocoimgs/coco_images/coco/000000397729.jpg
#   inflating: cocoimgs/coco_images/coco/000000530915.jpg
#   inflating: cocoimgs/coco_images/coco/000000135442.jpg
#   inflating: cocoimgs/coco_images/coco/000000394546.jpg
#   inflating: cocoimgs/coco_images/coco/000000137241.jpg
#   inflating: cocoimgs/coco_images/coco/000000400168.jpg
#   inflating: cocoimgs/coco_images/coco/000000530901.jpg
#   inflating: cocoimgs/coco_images/coco/000000133999.jpg
#   inflating: cocoimgs/coco_images/coco/000000399710.jpg
#   inflating: cocoimgs/coco_images/coco/000000266908.jpg
#   inflating: cocoimgs/coco_images/coco/000000398426.jpg
#   inflating: cocoimgs/coco_images/coco/000000263858.jpg
#   inflating: cocoimgs/coco_images/coco/000000134760.jpg
#   inflating: cocoimgs/coco_images/coco/000000527299.jpg
#   inflating: cocoimgs/coco_images/coco/000000524790.jpg
#   inflating: cocoimgs/coco_images/coco/000000397701.jpg
#   inflating: cocoimgs/coco_images/coco/000000529539.jpg
#   inflating: cocoimgs/coco_images/coco/000000002239.jpg
#   inflating: cocoimgs/coco_images/coco/000000525303.jpg
#   inflating: cocoimgs/coco_images/coco/000000262561.jpg
#   inflating: cocoimgs/coco_images/coco/000000136836.jpg
#   inflating: cocoimgs/coco_images/coco/000000395843.jpg
#   inflating: cocoimgs/coco_images/coco/000000262207.jpg
#   inflating: cocoimgs/coco_images/coco/000000269346.jpg
#   inflating: cocoimgs/coco_images/coco/000000268058.jpg
#   inflating: cocoimgs/coco_images/coco/000000007355.jpg
#   inflating: cocoimgs/coco_images/coco/000000002563.jpg
#   inflating: cocoimgs/coco_images/coco/000000529277.jpg
#   inflating: cocoimgs/coco_images/coco/000000530726.jpg
#   inflating: cocoimgs/coco_images/coco/000000398397.jpg
#   inflating: cocoimgs/coco_images/coco/000000000360.jpg
#   inflating: cocoimgs/coco_images/coco/000000399937.jpg
#   inflating: cocoimgs/coco_images/coco/000000002211.jpg
#   inflating: cocoimgs/coco_images/coco/000000265971.jpg
#   inflating: cocoimgs/coco_images/coco/000000004489.jpg
#   inflating: cocoimgs/coco_images/coco/000000133543.jpg
#   inflating: cocoimgs/coco_images/coco/000000399512.jpg
#   inflating: cocoimgs/coco_images/coco/000000269187.jpg
#   inflating: cocoimgs/coco_images/coco/000000399274.jpg
#   inflating: cocoimgs/coco_images/coco/000000138370.jpg
#   inflating: cocoimgs/coco_images/coco/000000398142.jpg
#   inflating: cocoimgs/coco_images/coco/000000395314.jpg
#   inflating: cocoimgs/coco_images/coco/000000400430.jpg
#   inflating: cocoimgs/coco_images/coco/000000265781.jpg
#   inflating: cocoimgs/coco_images/coco/000000135683.jpg
#   inflating: cocoimgs/coco_images/coco/000000005032.jpg
#   inflating: cocoimgs/coco_images/coco/000000525667.jpg
#   inflating: cocoimgs/coco_images/coco/000000264474.jpg
#   inflating: cocoimgs/coco_images/coco/000000003325.jpg
#   inflating: cocoimgs/coco_images/coco/000000398803.jpg
#   inflating: cocoimgs/coco_images/coco/000000528425.jpg
#   inflating: cocoimgs/coco_images/coco/000000398817.jpg
#   inflating: cocoimgs/coco_images/coco/000000133580.jpg
#   inflating: cocoimgs/coco_images/coco/000000005740.jpg
#   inflating: cocoimgs/coco_images/coco/000000393942.jpg
#   inflating: cocoimgs/coco_images/coco/000000003457.jpg
#   inflating: cocoimgs/coco_images/coco/000000394793.jpg
#   inflating: cocoimgs/coco_images/coco/000000134589.jpg
#   inflating: cocoimgs/coco_images/coco/000000263327.jpg
#   inflating: cocoimgs/coco_images/coco/000000530256.jpg
#   inflating: cocoimgs/coco_images/coco/000000396812.jpg
#   inflating: cocoimgs/coco_images/coco/000000002007.jpg
#   inflating: cocoimgs/coco_images/coco/000000530242.jpg
#   inflating: cocoimgs/coco_images/coco/000000524551.jpg
#   inflating: cocoimgs/coco_images/coco/000000400395.jpg
#   inflating: cocoimgs/coco_images/coco/000000531602.jpg
#   inflating: cocoimgs/coco_images/coco/000000001244.jpg
#   inflating: cocoimgs/coco_images/coco/000000266273.jpg
#   inflating: cocoimgs/coco_images/coco/000000527060.jpg
#   inflating: cocoimgs/coco_images/coco/000000266515.jpg
#   inflating: cocoimgs/coco_images/coco/000000001536.jpg
#   inflating: cocoimgs/coco_images/coco/000000137090.jpg
#   inflating: cocoimgs/coco_images/coco/000000530508.jpg
#   inflating: cocoimgs/coco_images/coco/000000134599.jpg
#   inflating: cocoimgs/coco_images/coco/000000006517.jpg
#   inflating: cocoimgs/coco_images/coco/000000530520.jpg
#   inflating: cocoimgs/coco_images/coco/000000265020.jpg
#   inflating: cocoimgs/coco_images/coco/000000268510.jpg
#   inflating: cocoimgs/coco_images/coco/000000529065.jpg
#   inflating: cocoimgs/coco_images/coco/000000527048.jpg
#   inflating: cocoimgs/coco_images/coco/000000263323.jpg
#   inflating: cocoimgs/coco_images/coco/000000269183.jpg
#   inflating: cocoimgs/coco_images/coco/000000396143.jpg
#   inflating: cocoimgs/coco_images/coco/000000393985.jpg
#   inflating: cocoimgs/coco_images/coco/000000135122.jpg
#   inflating: cocoimgs/coco_images/coco/000000396157.jpg
#   inflating: cocoimgs/coco_images/coco/000000267192.jpg
#   inflating: cocoimgs/coco_images/coco/000000136365.jpg
#   inflating: cocoimgs/coco_images/coco/000000530285.jpg
#   inflating: cocoimgs/coco_images/coco/000000527935.jpg
#   inflating: cocoimgs/coco_images/coco/000000397513.jpg
#   inflating: cocoimgs/coco_images/coco/000000395304.jpg
#   inflating: cocoimgs/coco_images/coco/000000395462.jpg
#   inflating: cocoimgs/coco_images/coco/000000266298.jpg
#   inflating: cocoimgs/coco_images/coco/000000399258.jpg
#   inflating: cocoimgs/coco_images/coco/000000529529.jpg
#   inflating: cocoimgs/coco_images/coco/000000531366.jpg
#   inflating: cocoimgs/coco_images/coco/000000001720.jpg
#   inflating: cocoimgs/coco_images/coco/000000002229.jpg
#   inflating: cocoimgs/coco_images/coco/000000395853.jpg
#   inflating: cocoimgs/coco_images/coco/000000266071.jpg
#   inflating: cocoimgs/coco_images/coco/000000136832.jpg
#   inflating: cocoimgs/coco_images/coco/000000262565.jpg
#   inflating: cocoimgs/coco_images/coco/000000529515.jpg
#   inflating: cocoimgs/coco_images/coco/000000267435.jpg
#   inflating: cocoimgs/coco_images/coco/000000529273.jpg
#   inflating: cocoimgs/coco_images/coco/000000006715.jpg
#   inflating: cocoimgs/coco_images/coco/000000265550.jpg
#   inflating: cocoimgs/coco_images/coco/000000002567.jpg
#   inflating: cocoimgs/coco_images/coco/000000000370.jpg
#   inflating: cocoimgs/coco_images/coco/000000263647.jpg
#   inflating: cocoimgs/coco_images/coco/000000264128.jpg
#   inflating: cocoimgs/coco_images/coco/000000265236.jpg
#   inflating: cocoimgs/coco_images/coco/000000131152.jpg
#   inflating: cocoimgs/coco_images/coco/000000004843.jpg
#   inflating: cocoimgs/coco_images/coco/000000269381.jpg
#   inflating: cocoimgs/coco_images/coco/000000395890.jpg
#   inflating: cocoimgs/coco_images/coco/000000397705.jpg
#   inflating: cocoimgs/coco_images/coco/000000134770.jpg
#   inflating: cocoimgs/coco_images/coco/000000397063.jpg
#   inflating: cocoimgs/coco_images/coco/000000396369.jpg
#   inflating: cocoimgs/coco_images/coco/000000264855.jpg
#   inflating: cocoimgs/coco_images/coco/000000268909.jpg
#   inflating: cocoimgs/coco_images/coco/000000264712.jpg
#   inflating: cocoimgs/coco_images/coco/000000525501.jpg
#   inflating: cocoimgs/coco_images/coco/000000526008.jpg
#   inflating: cocoimgs/coco_images/coco/000000133194.jpg
#   inflating: cocoimgs/coco_images/coco/000000134837.jpg
#   inflating: cocoimgs/coco_images/coco/000000395933.jpg
#   inflating: cocoimgs/coco_images/coco/000000525273.jpg
#   inflating: cocoimgs/coco_images/coco/000000394393.jpg
#   inflating: cocoimgs/coco_images/coco/000000266677.jpg
#   inflating: cocoimgs/coco_images/coco/000000268882.jpg
#   inflating: cocoimgs/coco_images/coco/000000265356.jpg
#   inflating: cocoimgs/coco_images/coco/000000001668.jpg
#   inflating: cocoimgs/coco_images/coco/000000006107.jpg
#   inflating: cocoimgs/coco_images/coco/000000530656.jpg
#   inflating: cocoimgs/coco_images/coco/000000524623.jpg
#   inflating: cocoimgs/coco_images/coco/000000263041.jpg
#   inflating: cocoimgs/coco_images/coco/000000131967.jpg
#   inflating: cocoimgs/coco_images/coco/000000005368.jpg
#   inflating: cocoimgs/coco_images/coco/000000006675.jpg
#   inflating: cocoimgs/coco_images/coco/000000268100.jpg
#   inflating: cocoimgs/coco_images/coco/000000530124.jpg
#   inflating: cocoimgs/coco_images/coco/000000267555.jpg
#   inflating: cocoimgs/coco_images/coco/000000004704.jpg
#   inflating: cocoimgs/coco_images/coco/000000000589.jpg
#   inflating: cocoimgs/coco_images/coco/000000006846.jpg
#   inflating: cocoimgs/coco_images/coco/000000394436.jpg
#   inflating: cocoimgs/coco_images/coco/000000396221.jpg
#   inflating: cocoimgs/coco_images/coco/000000134176.jpg
#   inflating: cocoimgs/coco_images/coco/000000133619.jpg
#   inflating: cocoimgs/coco_images/coco/000000397665.jpg
#   inflating: cocoimgs/coco_images/coco/000000001330.jpg
#   inflating: cocoimgs/coco_images/coco/000000529139.jpg
#   inflating: cocoimgs/coco_images/coco/000000005156.jpg
#   inflating: cocoimgs/coco_images/coco/000000262161.jpg
#   inflating: cocoimgs/coco_images/coco/000000002639.jpg
#   inflating: cocoimgs/coco_images/coco/000000131581.jpg
#   inflating: cocoimgs/coco_images/coco/000000394185.jpg
#   inflating: cocoimgs/coco_images/coco/000000006339.jpg
#   inflating: cocoimgs/coco_images/coco/000000266461.jpg
#   inflating: cocoimgs/coco_images/coco/000000396792.jpg
#   inflating: cocoimgs/coco_images/coco/000000529887.jpg
#   inflating: cocoimgs/coco_images/coco/000000000984.jpg
#   inflating: cocoimgs/coco_images/coco/000000527666.jpg
#   inflating: cocoimgs/coco_images/coco/000000137682.jpg
#   inflating: cocoimgs/coco_images/coco/000000393826.jpg
#   inflating: cocoimgs/coco_images/coco/000000262175.jpg
#   inflating: cocoimgs/coco_images/coco/000000264504.jpg
#   inflating: cocoimgs/coco_images/coco/000000268316.jpg
#   inflating: cocoimgs/coco_images/coco/000000396976.jpg
#   inflating: cocoimgs/coco_images/coco/000000526222.jpg
#   inflating: cocoimgs/coco_images/coco/000000394620.jpg
#   inflating: cocoimgs/coco_images/coco/000000138200.jpg
#   inflating: cocoimgs/coco_images/coco/000000265815.jpg
#   inflating: cocoimgs/coco_images/coco/000000528582.jpg
#   inflating: cocoimgs/coco_images/coco/000000393629.jpg
#   inflating: cocoimgs/coco_images/coco/000000529850.jpg
#   inflating: cocoimgs/coco_images/coco/000000399476.jpg
#   inflating: cocoimgs/coco_images/coco/000000137127.jpg
#   inflating: cocoimgs/coco_images/coco/000000132077.jpg
#   inflating: cocoimgs/coco_images/coco/000000133369.jpg
#   inflating: cocoimgs/coco_images/coco/000000397467.jpg
#   inflating: cocoimgs/coco_images/coco/000000136563.jpg
#   inflating: cocoimgs/coco_images/coco/000000400554.jpg
#   inflating: cocoimgs/coco_images/coco/000000394608.jpg
#   inflating: cocoimgs/coco_images/coco/000000005802.jpg
#   inflating: cocoimgs/coco_images/coco/000000395271.jpg
#   inflating: cocoimgs/coco_images/coco/000000132710.jpg
#   inflating: cocoimgs/coco_images/coco/000000526592.jpg
#   inflating: cocoimgs/coco_images/coco/000000135057.jpg
#   inflating: cocoimgs/coco_images/coco/000000394635.jpg
#   inflating: cocoimgs/coco_images/coco/000000006489.jpg
#   inflating: cocoimgs/coco_images/coco/000000138201.jpg
#   inflating: cocoimgs/coco_images/coco/000000002823.jpg
#   inflating: cocoimgs/coco_images/coco/000000265814.jpg
#   inflating: cocoimgs/coco_images/coco/000000137654.jpg
#   inflating: cocoimgs/coco_images/coco/000000131225.jpg
#   inflating: cocoimgs/coco_images/coco/000000527868.jpg
#   inflating: cocoimgs/coco_images/coco/000000528583.jpg
#   inflating: cocoimgs/coco_images/coco/000000000761.jpg
#   inflating: cocoimgs/coco_images/coco/000000529676.jpg
#   inflating: cocoimgs/coco_images/coco/000000005619.jpg
#   inflating: cocoimgs/coco_images/coco/000000262148.jpg
#   inflating: cocoimgs/coco_images/coco/000000001319.jpg
#   inflating: cocoimgs/coco_images/coco/000000004275.jpg
#   inflating: cocoimgs/coco_images/coco/000000524420.jpg
#   inflating: cocoimgs/coco_images/coco/000000525058.jpg
#   inflating: cocoimgs/coco_images/coco/000000527897.jpg
#   inflating: cocoimgs/coco_images/coco/000000394190.jpg
#   inflating: cocoimgs/coco_images/coco/000000135094.jpg
#   inflating: cocoimgs/coco_images/coco/000000000985.jpg
#   inflating: cocoimgs/coco_images/coco/000000003532.jpg
#   inflating: cocoimgs/coco_images/coco/000000264511.jpg
#   inflating: cocoimgs/coco_images/coco/000000131580.jpg
#   inflating: cocoimgs/coco_images/coco/000000525702.jpg
#   inflating: cocoimgs/coco_images/coco/000000529886.jpg
#   inflating: cocoimgs/coco_images/coco/000000396793.jpg
#   inflating: cocoimgs/coco_images/coco/000000006338.jpg
#   inflating: cocoimgs/coco_images/coco/000000003917.jpg
#   inflating: cocoimgs/coco_images/coco/000000262389.jpg
#   inflating: cocoimgs/coco_images/coco/000000397664.jpg
#   inflating: cocoimgs/coco_images/coco/000000134177.jpg
#   inflating: cocoimgs/coco_images/coco/000000528971.jpg
#   inflating: cocoimgs/coco_images/coco/000000399885.jpg
#   inflating: cocoimgs/coco_images/coco/000000263083.jpg
#   inflating: cocoimgs/coco_images/coco/000000133142.jpg
#   inflating: cocoimgs/coco_images/coco/000000137442.jpg
#   inflating: cocoimgs/coco_images/coco/000000397658.jpg
#   inflating: cocoimgs/coco_images/coco/000000268854.jpg
#   inflating: cocoimgs/coco_images/coco/000000137330.jpg
#   inflating: cocoimgs/coco_images/coco/000000134639.jpg
#   inflating: cocoimgs/coco_images/coco/000000006847.jpg
#   inflating: cocoimgs/coco_images/coco/000000526021.jpg
#   inflating: cocoimgs/coco_images/coco/000000004711.jpg
#   inflating: cocoimgs/coco_images/coco/000000528018.jpg
#   inflating: cocoimgs/coco_images/coco/000000528030.jpg
#   inflating: cocoimgs/coco_images/coco/000000004739.jpg
#   inflating: cocoimgs/coco_images/coco/000000136953.jpg
#   inflating: cocoimgs/coco_images/coco/000000262404.jpg
#   inflating: cocoimgs/coco_images/coco/000000525266.jpg
#   inflating: cocoimgs/coco_images/coco/000000268897.jpg
#   inflating: cocoimgs/coco_images/coco/000000397857.jpg
#   inflating: cocoimgs/coco_images/coco/000000001655.jpg
#   inflating: cocoimgs/coco_images/coco/000000268129.jpg
#   inflating: cocoimgs/coco_images/coco/000000526196.jpg
#   inflating: cocoimgs/coco_images/coco/000000398423.jpg
#   inflating: cocoimgs/coco_images/coco/000000393576.jpg
#   inflating: cocoimgs/coco_images/coco/000000263685.jpg
#   inflating: cocoimgs/coco_images/coco/000000395113.jpg
#   inflating: cocoimgs/coco_images/coco/000000265586.jpg
#   inflating: cocoimgs/coco_images/coco/000000132328.jpg
#   inflating: cocoimgs/coco_images/coco/000000134981.jpg
#   inflating: cocoimgs/coco_images/coco/000000396354.jpg
#   inflating: cocoimgs/coco_images/coco/000000131621.jpg
#   inflating: cocoimgs/coco_images/coco/000000137250.jpg
#   inflating: cocoimgs/coco_images/coco/000000526800.jpg
#   inflating: cocoimgs/coco_images/coco/000000263875.jpg
#   inflating: cocoimgs/coco_images/coco/000000003693.jpg
#   inflating: cocoimgs/coco_images/coco/000000530904.jpg
#   inflating: cocoimgs/coco_images/coco/000000265237.jpg
#   inflating: cocoimgs/coco_images/coco/000000529500.jpg
#   inflating: cocoimgs/coco_images/coco/000000399932.jpg
#   inflating: cocoimgs/coco_images/coco/000000133963.jpg
#   inflating: cocoimgs/coco_images/coco/000000004665.jpg
#   inflating: cocoimgs/coco_images/coco/000000131812.jpg
#   inflating: cocoimgs/coco_images/coco/000000394580.jpg
#   inflating: cocoimgs/coco_images/coco/000000001053.jpg
#   inflating: cocoimgs/coco_images/coco/000000268049.jpg
#   inflating: cocoimgs/coco_images/coco/000000527277.jpg
#   inflating: cocoimgs/coco_images/coco/000000136833.jpg
#   inflating: cocoimgs/coco_images/coco/000000267408.jpg
#   inflating: cocoimgs/coco_images/coco/000000269343.jpg
#   inflating: cocoimgs/coco_images/coco/000000527263.jpg
#   inflating: cocoimgs/coco_images/coco/000000132670.jpg
#   inflating: cocoimgs/coco_images/coco/000000266299.jpg
#   inflating: cocoimgs/coco_images/coco/000000397274.jpg
#   inflating: cocoimgs/coco_images/coco/000000395463.jpg
#   inflating: cocoimgs/coco_images/coco/000000132102.jpg
#   inflating: cocoimgs/coco_images/coco/000000398153.jpg
#   inflating: cocoimgs/coco_images/coco/000000530284.jpg
#   inflating: cocoimgs/coco_images/coco/000000395311.jpg
#   inflating: cocoimgs/coco_images/coco/000000005962.jpg
#   inflating: cocoimgs/coco_images/coco/000000395339.jpg
#   inflating: cocoimgs/coco_images/coco/000000137052.jpg
#   inflating: cocoimgs/coco_images/coco/000000001292.jpg
#   inflating: cocoimgs/coco_images/coco/000000393984.jpg
#   inflating: cocoimgs/coco_images/coco/000000400409.jpg
#   inflating: cocoimgs/coco_images/coco/000000004498.jpg
#   inflating: cocoimgs/coco_images/coco/000000394033.jpg
#   inflating: cocoimgs/coco_images/coco/000000398609.jpg
#   inflating: cocoimgs/coco_images/coco/000000002764.jpg
#   inflating: cocoimgs/coco_images/coco/000000263450.jpg
#   inflating: cocoimgs/coco_images/coco/000000003320.jpg
#   inflating: cocoimgs/coco_images/coco/000000525104.jpg
#   inflating: cocoimgs/coco_images/coco/000000530509.jpg
#   inflating: cocoimgs/coco_images/coco/000000002758.jpg
#   inflating: cocoimgs/coco_images/coco/000000137085.jpg
#   inflating: cocoimgs/coco_images/coco/000000526419.jpg
#   inflating: cocoimgs/coco_images/coco/000000001523.jpg
#   inflating: cocoimgs/coco_images/coco/000000268539.jpg
#   inflating: cocoimgs/coco_images/coco/000000525660.jpg
#   inflating: cocoimgs/coco_images/coco/000000528344.jpg
#   inflating: cocoimgs/coco_images/coco/000000527711.jpg
#   inflating: cocoimgs/coco_images/coco/000000525106.jpg
#   inflating: cocoimgs/coco_images/coco/000000262770.jpg
#   inflating: cocoimgs/coco_images/coco/000000132841.jpg
#   inflating: cocoimgs/coco_images/coco/000000135690.jpg
#   inflating: cocoimgs/coco_images/coco/000000394794.jpg
#   inflating: cocoimgs/coco_images/coco/000000005021.jpg
#   inflating: cocoimgs/coco_images/coco/000000003478.jpg
#   inflating: cocoimgs/coco_images/coco/000000394964.jpg
#   inflating: cocoimgs/coco_images/coco/000000137911.jpg
#   inflating: cocoimgs/coco_images/coco/000000265037.jpg
#   inflating: cocoimgs/coco_images/coco/000000262980.jpg
#   inflating: cocoimgs/coco_images/coco/000000007178.jpg
#   inflating: cocoimgs/coco_images/coco/000000002014.jpg
#   inflating: cocoimgs/coco_images/coco/000000265023.jpg
#   inflating: cocoimgs/coco_images/coco/000000000165.jpg
#   inflating: cocoimgs/coco_images/coco/000000267152.jpg
#   inflating: cocoimgs/coco_images/coco/000000001290.jpg
#   inflating: cocoimgs/coco_images/coco/000000400379.jpg
#   inflating: cocoimgs/coco_images/coco/000000138405.jpg
#   inflating: cocoimgs/coco_images/coco/000000135135.jpg
#   inflating: cocoimgs/coco_images/coco/000000267813.jpg
#   inflating: cocoimgs/coco_images/coco/000000003493.jpg
#   inflating: cocoimgs/coco_images/coco/000000132114.jpg
#   inflating: cocoimgs/coco_images/coco/000000398623.jpg
#   inflating: cocoimgs/coco_images/coco/000000394019.jpg
#   inflating: cocoimgs/coco_images/coco/000000530286.jpg
#   inflating: cocoimgs/coco_images/coco/000000398637.jpg
#   inflating: cocoimgs/coco_images/coco/000000524595.jpg
#   inflating: cocoimgs/coco_images/coco/000000269355.jpg
#   inflating: cocoimgs/coco_images/coco/000000134940.jpg
#   inflating: cocoimgs/coco_images/coco/000000529258.jpg
#   inflating: cocoimgs/coco_images/coco/000000135486.jpg
#   inflating: cocoimgs/coco_images/coco/000000262200.jpg
#   inflating: cocoimgs/coco_images/coco/000000004129.jpg
#   inflating: cocoimgs/coco_images/coco/000000394596.jpg
#   inflating: cocoimgs/coco_images/coco/000000395850.jpg
#   inflating: cocoimgs/coco_images/coco/000000268739.jpg
#   inflating: cocoimgs/coco_images/coco/000000527507.jpg
#   inflating: cocoimgs/coco_images/coco/000000003134.jpg
#   inflating: cocoimgs/coco_images/coco/000000268711.jpg
#   inflating: cocoimgs/coco_images/coco/000000267422.jpg
#   inflating: cocoimgs/coco_images/coco/000000000415.jpg
#   inflating: cocoimgs/coco_images/coco/000000265553.jpg
#   inflating: cocoimgs/coco_images/coco/000000131804.jpg
#   inflating: cocoimgs/coco_images/coco/000000526143.jpg
#   inflating: cocoimgs/coco_images/coco/000000529270.jpg
#   inflating: cocoimgs/coco_images/coco/000000265547.jpg
#   inflating: cocoimgs/coco_images/coco/000000264659.jpg
#   inflating: cocoimgs/coco_images/coco/000000400190.jpg
#   inflating: cocoimgs/coco_images/coco/000000263136.jpg
#   inflating: cocoimgs/coco_images/coco/000000136819.jpg
#   inflating: cocoimgs/coco_images/coco/000000003685.jpg
#   inflating: cocoimgs/coco_images/coco/000000530912.jpg
#   inflating: cocoimgs/coco_images/coco/000000395893.jpg
#   inflating: cocoimgs/coco_images/coco/000000138175.jpg
#   inflating: cocoimgs/coco_images/coco/000000004840.jpg
#   inflating: cocoimgs/coco_images/coco/000000263687.jpg
#   inflating: cocoimgs/coco_images/coco/000000134001.jpg
#   inflating: cocoimgs/coco_images/coco/000000528807.jpg
#   inflating: cocoimgs/coco_images/coco/000000398435.jpg
#   inflating: cocoimgs/coco_images/coco/000000396418.jpg
#   inflating: cocoimgs/coco_images/coco/000000005425.jpg
#   inflating: cocoimgs/coco_images/coco/000000007232.jpg
# ...
#   inflating: cocoimgs/coco_images/coco/000000530925.jpg
#   inflating: cocoimgs/coco_images/coco/000000263101.jpg
#   inflating: cocoimgs/coco_images/coco/000000135499.jpg
#   inflating: cocoimgs/coco_images/coco/000000397094.jpg
#   inflating: cocoimgs/coco_images/coco/000000000436.jpg
#   inflating: cocoimgs/coco_images/coco/000000002235.jpg
#   inflating: cocoimgs/coco_images/coco/000000006053.jpg
#   inflating: cocoimgs/coco_images/coco/000000131833.jpg
#   inflating: cocoimgs/coco_images/coco/000000524777.jpg
#   inflating: cocoimgs/coco_images/coco/000000136184.jpg
#   inflating: cocoimgs/coco_images/coco/000000262545.jpg
#   inflating: cocoimgs/coco_images/coco/000000003103.jpg
#   inflating: cocoimgs/coco_images/coco/000000001700.jpg
#   inflating: cocoimgs/coco_images/coco/000000004678.jpg
#   inflating: cocoimgs/coco_images/coco/000000138195.jpg
#   inflating: cocoimgs/coco_images/coco/000000006709.jpg
#   inflating: cocoimgs/coco_images/coco/000000132889.jpg
#   inflating: cocoimgs/coco_images/coco/000000395324.jpg
#   inflating: cocoimgs/coco_images/coco/000000132137.jpg
#   inflating: cocoimgs/coco_images/coco/000000133229.jpg
#   inflating: cocoimgs/coco_images/coco/000000134552.jpg
#   inflating: cocoimgs/coco_images/coco/000000397241.jpg
#   inflating: cocoimgs/coco_images/coco/000000394748.jpg
#   inflating: cocoimgs/coco_images/coco/000000138368.jpg
#   inflating: cocoimgs/coco_images/coco/000000131364.jpg
#   inflating: cocoimgs/coco_images/coco/000000395318.jpg
#   inflating: cocoimgs/coco_images/coco/000000137715.jpg
#   inflating: cocoimgs/coco_images/coco/000000396611.jpg
#   inflating: cocoimgs/coco_images/coco/000000135664.jpg
#   inflating: cocoimgs/coco_images/coco/000000265799.jpg
#   inflating: cocoimgs/coco_images/coco/000000399250.jpg
#   inflating: cocoimgs/coco_images/coco/000000527083.jpg
#   inflating: cocoimgs/coco_images/coco/000000529910.jpg
#   inflating: cocoimgs/coco_images/coco/000000267830.jpg
#   inflating: cocoimgs/coco_images/coco/000000525119.jpg
#   inflating: cocoimgs/coco_images/coco/000000000634.jpg
#   inflating: cocoimgs/coco_images/coco/000000530272.jpg
#   inflating: cocoimgs/coco_images/coco/000000396188.jpg
#   inflating: cocoimgs/coco_images/coco/000000530500.jpg
#   inflating: cocoimgs/coco_images/coco/000000526362.jpg
#   inflating: cocoimgs/coco_images/coco/000000531178.jpg
#   inflating: cocoimgs/coco_images/coco/000000137926.jpg
#   inflating: cocoimgs/coco_images/coco/000000007167.jpg
#   inflating: cocoimgs/coco_images/coco/000000264336.jpg
#   inflating: cocoimgs/coco_images/coco/000000262747.jpg
#   inflating: cocoimgs/coco_images/coco/000000005016.jpg
#   inflating: cocoimgs/coco_images/coco/000000527054.jpg
#   inflating: cocoimgs/coco_images/coco/000000269174.jpg
#   inflating: cocoimgs/coco_images/coco/000000001270.jpg
#   inflating: cocoimgs/coco_images/coco/000000527040.jpg
#   inflating: cocoimgs/coco_images/coco/000000264322.jpg
#   inflating: cocoimgs/coco_images/coco/000000531144.jpg
#   inflating: cocoimgs/coco_images/coco/000000268268.jpg
#   inflating: cocoimgs/coco_images/coco/000000525899.jpg
#   inflating: cocoimgs/coco_images/coco/000000132874.jpg
#   inflating: cocoimgs/coco_images/coco/000000004478.jpg
#   inflating: cocoimgs/coco_images/coco/000000005028.jpg
#   inflating: cocoimgs/coco_images/coco/000000007159.jpg
#   inflating: cocoimgs/coco_images/coco/000000396820.jpg
#   inflating: cocoimgs/coco_images/coco/000000527718.jpg
#   inflating: cocoimgs/coco_images/coco/000000006253.jpg
#   inflating: cocoimgs/coco_images/coco/000000526360.jpg
#   inflating: cocoimgs/coco_images/coco/000000524577.jpg
#   inflating: cocoimgs/coco_images/coco/000000525682.jpg
#   inflating: cocoimgs/coco_images/coco/000000398158.jpg
#   inflating: cocoimgs/coco_images/coco/000000135666.jpg
#   inflating: cocoimgs/coco_images/coco/000000262786.jpg
#   inflating: cocoimgs/coco_images/coco/000000131366.jpg
#   inflating: cocoimgs/coco_images/coco/000000137703.jpg
#   inflating: cocoimgs/coco_images/coco/000000399534.jpg
#   inflating: cocoimgs/coco_images/coco/000000399252.jpg
#   inflating: cocoimgs/coco_images/coco/000000265943.jpg
#   inflating: cocoimgs/coco_images/coco/000000398164.jpg
#   inflating: cocoimgs/coco_images/coco/000000395326.jpg
#   inflating: cocoimgs/coco_images/coco/000000000839.jpg
#   inflating: cocoimgs/coco_images/coco/000000133559.jpg
#   inflating: cocoimgs/coco_images/coco/000000397525.jpg
#   inflating: cocoimgs/coco_images/coco/000000262976.jpg
#   inflating: cocoimgs/coco_images/coco/000000393743.jpg
#   inflating: cocoimgs/coco_images/coco/000000394992.jpg
#   inflating: cocoimgs/coco_images/coco/000000531350.jpg
#   inflating: cocoimgs/coco_images/coco/000000399939.jpg
#   inflating: cocoimgs/coco_images/coco/000000527532.jpg
#   inflating: cocoimgs/coco_images/coco/000000262221.jpg
#   inflating: cocoimgs/coco_images/coco/000000395865.jpg
#   inflating: cocoimgs/coco_images/coco/000000004108.jpg
#   inflating: cocoimgs/coco_images/coco/000000528167.jpg
#   inflating: cocoimgs/coco_images/coco/000000269360.jpg
#   inflating: cocoimgs/coco_images/coco/000000262235.jpg
#   inflating: cocoimgs/coco_images/coco/000000268718.jpg
#   inflating: cocoimgs/coco_images/coco/000000399905.jpg
#   inflating: cocoimgs/coco_images/coco/000000131825.jpg
#   inflating: cocoimgs/coco_images/coco/000000003897.jpg
#   inflating: cocoimgs/coco_images/coco/000000524775.jpg
#   inflating: cocoimgs/coco_images/coco/000000268042.jpg
#   inflating: cocoimgs/coco_images/coco/000000006051.jpg
#   inflating: cocoimgs/coco_images/coco/000000133940.jpg
#   inflating: cocoimgs/coco_images/coco/000000267417.jpg
#   inflating: cocoimgs/coco_images/coco/000000265200.jpg
#   inflating: cocoimgs/coco_images/coco/000000526837.jpg
#   inflating: cocoimgs/coco_images/coco/000000394560.jpg
#   inflating: cocoimgs/coco_images/coco/000000524946.jpg
#   inflating: cocoimgs/coco_images/coco/000000527283.jpg
#   inflating: cocoimgs/coco_images/coco/000000398428.jpg
#   inflating: cocoimgs/coco_images/coco/000000137501.jpg
#   inflating: cocoimgs/coco_images/coco/000000399078.jpg
#   inflating: cocoimgs/coco_images/coco/000000268095.jpg
#   inflating: cocoimgs/coco_images/coco/000000397041.jpg
#   inflating: cocoimgs/coco_images/coco/000000393227.jpg
#   inflating: cocoimgs/coco_images/coco/000000136145.jpg
#   inflating: cocoimgs/coco_images/coco/000000527446.jpg
#   inflating: cocoimgs/coco_images/coco/000000531224.jpg
#   inflating: cocoimgs/coco_images/coco/000000003713.jpg
#   inflating: cocoimgs/coco_images/coco/000000131979.jpg
#   inflating: cocoimgs/coco_images/coco/000000005376.jpg
#   inflating: cocoimgs/coco_images/coco/000000136970.jpg
#   inflating: cocoimgs/coco_images/coco/000000528761.jpg
#   inflating: cocoimgs/coco_images/coco/000000007207.jpg
#   inflating: cocoimgs/coco_images/coco/000000268644.jpg
#   inflating: cocoimgs/coco_images/coco/000000529457.jpg
#   inflating: cocoimgs/coco_images/coco/000000134829.jpg
#   inflating: cocoimgs/coco_images/coco/000000268122.jpg
#   inflating: cocoimgs/coco_images/coco/000000393384.jpg
#   inflating: cocoimgs/coco_images/coco/000000264718.jpg
#   inflating: cocoimgs/coco_images/coco/000000524601.jpg
#   inflating: cocoimgs/coco_images/coco/000000269228.jpg
#   inflating: cocoimgs/coco_images/coco/000000132294.jpg
#   inflating: cocoimgs/coco_images/coco/000000267205.jpg
#   inflating: cocoimgs/coco_images/coco/000000399865.jpg
#   inflating: cocoimgs/coco_images/coco/000000265374.jpg
#   inflating: cocoimgs/coco_images/coco/000000006870.jpg
#   inflating: cocoimgs/coco_images/coco/000000531581.jpg
#   inflating: cocoimgs/coco_images/coco/000000006864.jpg
#   inflating: cocoimgs/coco_images/coco/000000526957.jpg
#   inflating: cocoimgs/coco_images/coco/000000138008.jpg
#   inflating: cocoimgs/coco_images/coco/000000397135.jpg
#   inflating: cocoimgs/coco_images/coco/000000135538.jpg
#   inflating: cocoimgs/coco_images/coco/000000003920.jpg
#   inflating: cocoimgs/coco_images/coco/000000136757.jpg
#   inflating: cocoimgs/coco_images/coco/000000266866.jpg
#   inflating: cocoimgs/coco_images/coco/000000264526.jpg
#   inflating: cocoimgs/coco_images/coco/000000267985.jpg
#   inflating: cocoimgs/coco_images/coco/000000531032.jpg
#   inflating: cocoimgs/coco_images/coco/000000266443.jpg
#   inflating: cocoimgs/coco_images/coco/000000528563.jpg
#   inflating: cocoimgs/coco_images/coco/000000525721.jpg
#   inflating: cocoimgs/coco_images/coco/000000263275.jpg
#   inflating: cocoimgs/coco_images/coco/000000395291.jpg
#   inflating: cocoimgs/coco_images/coco/000000137844.jpg
#   inflating: cocoimgs/coco_images/coco/000000265176.jpg
#   inflating: cocoimgs/coco_images/coco/000000136596.jpg
#   inflating: cocoimgs/coco_images/coco/000000006327.jpg
#   inflating: cocoimgs/coco_images/coco/000000268334.jpg
#   inflating: cocoimgs/coco_images/coco/000000137105.jpg
#   inflating: cocoimgs/coco_images/coco/000000399332.jpg
#   inflating: cocoimgs/coco_images/coco/000000526599.jpg
#   inflating: cocoimgs/coco_images/coco/000000000965.jpg
#   inflating: cocoimgs/coco_images/coco/000000398992.jpg
#   inflating: cocoimgs/coco_images/coco/000000400238.jpg
#   inflating: cocoimgs/coco_images/coco/000000136541.jpg
#   inflating: cocoimgs/coco_images/coco/000000000781.jpg
#   inflating: cocoimgs/coco_images/coco/000000000795.jpg
#   inflating: cocoimgs/coco_images/coco/000000396997.jpg
#   inflating: cocoimgs/coco_images/coco/000000132733.jpg
#   inflating: cocoimgs/coco_images/coco/000000136555.jpg
#   inflating: cocoimgs/coco_images/coco/000000395520.jpg
#   inflating: cocoimgs/coco_images/coco/000000268484.jpg
#   inflating: cocoimgs/coco_images/coco/000000137886.jpg
#   inflating: cocoimgs/coco_images/coco/000000399441.jpg
#   inflating: cocoimgs/coco_images/coco/000000133410.jpg
#   inflating: cocoimgs/coco_images/coco/000000264296.jpg
#   inflating: cocoimgs/coco_images/coco/000000525085.jpg
#   inflating: cocoimgs/coco_images/coco/000000264282.jpg
#   inflating: cocoimgs/coco_images/coco/000000395284.jpg
#   inflating: cocoimgs/coco_images/coco/000000003538.jpg
#   inflating: cocoimgs/coco_images/coco/000000529126.jpg
#   inflating: cocoimgs/coco_images/coco/000000004243.jpg
#   inflating: cocoimgs/coco_images/coco/000000002154.jpg
#   inflating: cocoimgs/coco_images/coco/000000263512.jpg
#   inflating: cocoimgs/coco_images/coco/000000396941.jpg
#   inflating: cocoimgs/coco_images/coco/000000267774.jpg
#   inflating: cocoimgs/coco_images/coco/000000264255.jpg
#   inflating: cocoimgs/coco_images/coco/000000528562.jpg
#   inflating: cocoimgs/coco_images/coco/000000531033.jpg
#   inflating: cocoimgs/coco_images/coco/000000001307.jpg
#   inflating: cocoimgs/coco_images/coco/000000132901.jpg
#   inflating: cocoimgs/coco_images/coco/000000531027.jpg
#   inflating: cocoimgs/coco_images/coco/000000529668.jpg
#   inflating: cocoimgs/coco_images/coco/000000264241.jpg
#   inflating: cocoimgs/coco_images/coco/000000003276.jpg
#   inflating: cocoimgs/coco_images/coco/000000005388.jpg
#   inflating: cocoimgs/coco_images/coco/000000135539.jpg
#   inflating: cocoimgs/coco_images/coco/000000131763.jpg
#   inflating: cocoimgs/coco_images/coco/000000135263.jpg
#   inflating: cocoimgs/coco_images/coco/000000268876.jpg
#   inflating: cocoimgs/coco_images/coco/000000134169.jpg
#   inflating: cocoimgs/coco_images/coco/000000266697.jpg
#   inflating: cocoimgs/coco_images/coco/000000394415.jpg
#   inflating: cocoimgs/coco_images/coco/000000269229.jpg
#   inflating: cocoimgs/coco_images/coco/000000528984.jpg
#   inflating: cocoimgs/coco_images/coco/000000135288.jpg
#   inflating: cocoimgs/coco_images/coco/000000397685.jpg
#   inflating: cocoimgs/coco_images/coco/000000003048.jpg
#   inflating: cocoimgs/coco_images/coco/000000395092.jpg
#   inflating: cocoimgs/coco_images/coco/000000265407.jpg
#   inflating: cocoimgs/coco_images/coco/000000267210.jpg
#   inflating: cocoimgs/coco_images/coco/000000268123.jpg
#   inflating: cocoimgs/coco_images/coco/000000005377.jpg
#   inflating: cocoimgs/coco_images/coco/000000131978.jpg
#   inflating: cocoimgs/coco_images/coco/000000004069.jpg
#   inflating: cocoimgs/coco_images/coco/000000395904.jpg
#   inflating: cocoimgs/coco_images/coco/000000528006.jpg
#   inflating: cocoimgs/coco_images/coco/000000000569.jpg
#   inflating: cocoimgs/coco_images/coco/000000136971.jpg
#   inflating: cocoimgs/coco_images/coco/000000264043.jpg
#   inflating: cocoimgs/coco_images/coco/000000527447.jpg
#   inflating: cocoimgs/coco_images/coco/000000001924.jpg
#   inflating: cocoimgs/coco_images/coco/000000004684.jpg
#   inflating: cocoimgs/coco_images/coco/000000398367.jpg
#   inflating: cocoimgs/coco_images/coco/000000268094.jpg
#   inflating: cocoimgs/coco_images/coco/000000134747.jpg
#   inflating: cocoimgs/coco_images/coco/000000132336.jpg
#   inflating: cocoimgs/coco_images/coco/000000396362.jpg
#   inflating: cocoimgs/coco_images/coco/000000131617.jpg
#   inflating: cocoimgs/coco_images/coco/000000133766.jpg
#   inflating: cocoimgs/coco_images/coco/000000526188.jpg
#   inflating: cocoimgs/coco_images/coco/000000134948.jpg
#   inflating: cocoimgs/coco_images/coco/000000268043.jpg
#   inflating: cocoimgs/coco_images/coco/000000530701.jpg
#   inflating: cocoimgs/coco_images/coco/000000005559.jpg
#   inflating: cocoimgs/coco_images/coco/000000399910.jpg
#   inflating: cocoimgs/coco_images/coco/000000268725.jpg
#   inflating: cocoimgs/coco_images/coco/000000267402.jpg
#   inflating: cocoimgs/coco_images/coco/000000132493.jpg
#   inflating: cocoimgs/coco_images/coco/000000529522.jpg
#   inflating: cocoimgs/coco_images/coco/000000397929.jpg
#   inflating: cocoimgs/coco_images/coco/000000525318.jpg
#   inflating: cocoimgs/coco_images/coco/000000263664.jpg
#   inflating: cocoimgs/coco_images/coco/000000264645.jpg
#   inflating: cocoimgs/coco_images/coco/000000531423.jpg
#   inflating: cocoimgs/coco_images/coco/000000136811.jpg
#   inflating: cocoimgs/coco_images/coco/000000528600.jpg
#   inflating: cocoimgs/coco_images/coco/000000524984.jpg
#   inflating: cocoimgs/coco_images/coco/000000132120.jpg
#   inflating: cocoimgs/coco_images/coco/000000001298.jpg
#   inflating: cocoimgs/coco_images/coco/000000134551.jpg
#   inflating: cocoimgs/coco_images/coco/000000400371.jpg
#   inflating: cocoimgs/coco_images/coco/000000136346.jpg
#   inflating: cocoimgs/coco_images/coco/000000000192.jpg
#   inflating: cocoimgs/coco_images/coco/000000132652.jpg
#   inflating: cocoimgs/coco_images/coco/000000131373.jpg
#   inflating: cocoimgs/coco_images/coco/000000267199.jpg
#   inflating: cocoimgs/coco_images/coco/000000000810.jpg
#   inflating: cocoimgs/coco_images/coco/000000000623.jpg
#   inflating: cocoimgs/coco_images/coco/000000396821.jpg
#   inflating: cocoimgs/coco_images/coco/000000530265.jpg
#   inflating: cocoimgs/coco_images/coco/000000525668.jpg
#   inflating: cocoimgs/coco_images/coco/000000002752.jpg
#   inflating: cocoimgs/coco_images/coco/000000134586.jpg
#   inflating: cocoimgs/coco_images/coco/000000000151.jpg
#   inflating: cocoimgs/coco_images/coco/000000266278.jpg
#   inflating: cocoimgs/coco_images/coco/000000006520.jpg
#   inflating: cocoimgs/coco_images/coco/000000264309.jpg
#   inflating: cocoimgs/coco_images/coco/000000137931.jpg
#   inflating: cocoimgs/coco_images/coco/000000396835.jpg
#   inflating: cocoimgs/coco_images/coco/000000266250.jpg
#   inflating: cocoimgs/coco_images/coco/000000263328.jpg
#   inflating: cocoimgs/coco_images/coco/000000525640.jpg
#   inflating: cocoimgs/coco_images/coco/000000525898.jpg
#   inflating: cocoimgs/coco_images/coco/000000528364.jpg
#   inflating: cocoimgs/coco_images/coco/000000399284.jpg
#   inflating: cocoimgs/coco_images/coco/000000266244.jpg
#   inflating: cocoimgs/coco_images/coco/000000531153.jpg
#   inflating: cocoimgs/coco_images/coco/000000393971.jpg
# caution: excluded filename not matched:  *.DS_Store

# %%
import torch
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
from torchvision import transforms
from torch.utils.data import random_split

image_size = 256
batch_size = 16

transformer = transforms.Compose([
    transforms.CenterCrop(image_size),
    transforms.ToTensor() # ToTensor() changes the range of the values from [0, 255] to [0.0, 1.0]
])

cartoon_dataset = ImageFolder('cartoons/', transformer)
len_training_set = math.floor(len(cartoon_dataset) * 0.9)
len_valid_set = len(cartoon_dataset) - len_training_set

training_set, _ = random_split(cartoon_dataset, (len_training_set, len_valid_set))
cartoon_image_dataloader_train = DataLoader(training_set, batch_size, shuffle=True, num_workers=0)

smoothed_cartoon_dataset = ImageFolder('smoothed_cartoons/', transformer)
len_training_set = math.floor(len(smoothed_cartoon_dataset) * 0.9)
len_valid_set = len(smoothed_cartoon_dataset) - len_training_set
training_set, _ = random_split(smoothed_cartoon_dataset, (len_training_set, len_valid_set))
smoothed_cartoon_image_dataloader_train = DataLoader(training_set, batch_size, shuffle=True, num_workers=0)

photo_dataset = ImageFolder('coco_images/', transformer)
len_training_set = math.floor(len(photo_dataset) * 0.9)
len_valid_set = len(photo_dataset) - len_training_set
training_set, validation_set = random_split(photo_dataset, (len_training_set, len_valid_set))
photo_dataloader_train = DataLoader(training_set, batch_size, shuffle=True, num_workers=0)
photo_dataloader_valid = DataLoader(validation_set, batch_size, shuffle=True, num_workers=0)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if torch.cuda.is_available():
  print('Training on GPU')
else:
  print('Please connect to a GPU runtime')

# Config
batch_size = 11
image_size = 224
learning_rate = 1.5e-4
beta1, beta2 = (.5, .99)
weight_decay = 1e-4
epochs = 100

project_dir = "cartoongan"
os.makedirs(project_dir, exist_ok=True)
# Out:
# Please connect to a GPU runtime

# %%
# !wget
# !wget
# !wget

# %%
import matplotlib.pyplot as plt
import numpy as np

def show_sample_image(dataloader):
  iterator = iter(dataloader)
  sample_batch, _ = next(iterator)
  first_sample_image_of_batch = sample_batch[0]
  print(first_sample_image_of_batch.size())
  print("Current range: {} to {}".format(first_sample_image_of_batch.min(), first_sample_image_of_batch.max()))
  plt.imshow(np.transpose(first_sample_image_of_batch.numpy(), (1, 2, 0)))

show_sample_image(cartoon_image_dataloader_train)
# Out:
# torch.Size([3, 256, 256])
# Current range: 0.0 to 1.0

# %%
show_sample_image(smoothed_cartoon_image_dataloader_train)
# Out:
# torch.Size([3, 256, 256])
# Current range: 0.0235294122248888 to 1.0

# %%
show_sample_image(photo_dataloader_train)
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# <ipython-input-121-e342238dc288> in <cell line: 1>()
# ----> 1 show_sample_image(photo_dataloader_train)
#
# <ipython-input-115-7b6680fb6176> in show_sample_image(dataloader)
#       4 def show_sample_image(dataloader):
#       5   iterator = iter(dataloader)
# ----> 6   sample_batch, _ = next(iterator)
#       7   first_sample_image_of_batch = sample_batch[0]
#       8   print(first_sample_image_of_batch.size())
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     699                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700                 self._reset()  # type: ignore[call-arg]
# --> 701             data = self._next_data()
#     702             self._num_yielded += 1
#     703             if (
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     755     def _next_data(self):
#     756         index = self._next_index()  # may raise StopIteration
# --> 757         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758         if self._pin_memory:
#     759             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      48         if self.auto_collation:
#      49             if hasattr(self.dataset, "__getitems__") and self.dataset.__getitems__:
# ---> 50                 data = self.dataset.__getitems__(possibly_batched_index)
#      51             else:
#      52                 data = [self.dataset[idx] for idx in possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataset.py in __getitems__(self, indices)
#     418             return self.dataset.__getitems__([self.indices[idx] for idx in indices])  # type: ignore[attr-defined]
#     419         else:
# --> 420             return [self.dataset[self.indices[idx]] for idx in indices]
#     421
#     422     def __len__(self):
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataset.py in <listcomp>(.0)
#     418             return self.dataset.__getitems__([self.indices[idx] for idx in indices])  # type: ignore[attr-defined]
#     419         else:
# --> 420             return [self.dataset[self.indices[idx]] for idx in indices]
#     421
#     422     def __len__(self):
#
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py in __getitem__(self, index)
#     243         """
#     244         path, target = self.samples[index]
# --> 245         sample = self.loader(path)
#     246         if self.transform is not None:
#     247             sample = self.transform(sample)
#
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py in default_loader(path)
#     282         return accimage_loader(path)
#     283     else:
# --> 284         return pil_loader(path)
#     285
#     286
#
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py in pil_loader(path)
#     261     # open path as file to avoid ResourceWarning (https://github.com/python-pillow/Pillow/issues/835)
#     262     with open(path, "rb") as f:
# --> 263         img = Image.open(f)
#     264         return img.convert("RGB")
#     265
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3496         warnings.warn(message)
#    3497     msg = "cannot identify image file %r" % (filename if filename else fp)
# -> 3498     raise UnidentifiedImageError(msg)
#    3499
#    3500
#
# UnidentifiedImageError: cannot identify image file <_io.BufferedReader name='coco_images/__MACOSX/coco_images/coco/._000000269015.jpg'>

# %%
import os
import time
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.nn import BCELoss
from torchvision import models, transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, random_split
from torch import sigmoid
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm

# Define the Residual Block
class ResidualBlock(nn.Module):
    def __init__(self):
        super(ResidualBlock, self).__init__()
        self.conv_1 = nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1)
        self.conv_2 = nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1)
        self.norm_1 = nn.BatchNorm2d(256)
        self.norm_2 = nn.BatchNorm2d(256)

    def forward(self, x):
        output = self.norm_2(self.conv_2(F.relu(self.norm_1(self.conv_1(x)))))
        return output + x

# Define the Generator
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.conv_1 = nn.Conv2d(3, 64, kernel_size=7, stride=1, padding=3)
        self.norm_1 = nn.BatchNorm2d(64)

        # Down-convolution
        self.conv_2 = nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1)
        self.conv_3 = nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1)
        self.norm_2 = nn.BatchNorm2d(128)

        self.conv_4 = nn.Conv2d(128, 256, kernel_size=3, stride=2, padding=1)
        self.conv_5 = nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1)
        self.norm_3 = nn.BatchNorm2d(256)

        # Residual blocks
        residual_blocks = [ResidualBlock() for _ in range(8)]
        self.res = nn.Sequential(*residual_blocks)

        # Up-convolution
        self.conv_6 = nn.ConvTranspose2d(256, 128, kernel_size=3, stride=2, padding=1, output_padding=1)
        self.conv_7 = nn.ConvTranspose2d(128, 128, kernel_size=3, stride=1, padding=1)
        self.norm_4 = nn.BatchNorm2d(128)

        self.conv_8 = nn.ConvTranspose2d(128, 64, kernel_size=3, stride=2, padding=1, output_padding=1)
        self.conv_9 = nn.ConvTranspose2d(64, 64, kernel_size=3, stride=1, padding=1)
        self.norm_5 = nn.BatchNorm2d(64)

        self.conv_10 = nn.Conv2d(64, 3, kernel_size=7, stride=1, padding=3)

    def forward(self, x):
        x = F.relu(self.norm_1(self.conv_1(x)))

        x = F.relu(self.norm_2(self.conv_3(self.conv_2(x))))
        x = F.relu(self.norm_3(self.conv_5(self.conv_4(x))))

        x = self.res(x)

        x = F.relu(self.norm_4(self.conv_7(self.conv_6(x))))
        x = F.relu(self.norm_5(self.conv_9(self.conv_8(x))))

        x = self.conv_10(x)
        x = sigmoid(x)

        return x

# Define the Discriminator
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.conv_1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)

        self.conv_2 = nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1)
        self.conv_3 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.norm_1 = nn.BatchNorm2d(128)

        self.conv_4 = nn.Conv2d(128, 128, kernel_size=3, stride=2, padding=1)
        self.conv_5 = nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1)
        self.norm_2 = nn.BatchNorm2d(256)

        self.conv_6 = nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1)
        self.norm_3 = nn.BatchNorm2d(256)

        self.conv_7 = nn.Conv2d(256, 1, kernel_size=3, stride=1, padding=1)

    def forward(self, x):
        x = F.leaky_relu(self.conv_1(x), negative_slope=0.2)
        x = F.leaky_relu(self.norm_1(self.conv_3(F.leaky_relu(self.conv_2(x), negative_slope=0.2))), negative_slope=0.2)
        x = F.leaky_relu(self.norm_2(self.conv_5(F.leaky_relu(self.conv_4(x), negative_slope=0.2))), negative_slope=0.2)
        x = F.leaky_relu(self.norm_3(self.conv_6(x)), negative_slope=0.2)
        x = self.conv_7(x)
        x = sigmoid(x)
        return x

# Initialize the models
G = Generator()
D = Discriminator()

# Set up device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
if torch.cuda.is_available():
    print("Train on GPU.")
else:
    print("No cuda available")

G.to(device)
D.to(device)

# Load VGG16 model
project_dir = './CartoonGANModel'
os.makedirs(project_dir, exist_ok=True)
path_to_pretrained_vgg16 = os.path.join(project_dir, 'vgg_torch.pth')

try:
    # Load the state dictionary instead of the whole model
    vgg16 = models.vgg16(weights=None)  # weights=None for no pre-trained weights
    vgg16.load_state_dict(torch.load(path_to_pretrained_vgg16))
    vgg16 = vgg16.to(device)
except FileNotFoundError:
    # Download pretrained model and save its state dict
    vgg16 = models.vgg16(weights='IMAGENET1K_V1')  # Pretrained weights
    torch.save(vgg16.state_dict(), path_to_pretrained_vgg16)
    vgg16 = vgg16.to(device)

# Extract features up to conv4_3 (since conv4_4 doesn't exist in PyTorch VGG16)
feature_extractor = vgg16.features[:23]  # Layer 23 corresponds to conv4_3
for param in feature_extractor.parameters():
    param.requires_grad = False

# Define the Discriminator Loss
class DiscriminatorLoss(nn.Module):
    def __init__(self):
        super(DiscriminatorLoss, self).__init__()
        self.bce_loss = BCELoss()

    def forward(self, discriminator_output_of_cartoon_input,
                discriminator_output_of_cartoon_smoothed_input,
                discriminator_output_of_generated_image_input):

        return self._adversarial_loss(discriminator_output_of_cartoon_input,
                                      discriminator_output_of_cartoon_smoothed_input,
                                      discriminator_output_of_generated_image_input)

    def _adversarial_loss(self, discriminator_output_of_cartoon_input,
                          discriminator_output_of_cartoon_smoothed_input,
                          discriminator_output_of_generated_image_input):

        # Use zeros and ones with the same shape as the discriminator outputs
        zeros = torch.zeros_like(discriminator_output_of_cartoon_input)
        ones = torch.ones_like(discriminator_output_of_cartoon_input)

        d_loss_cartoon = self.bce_loss(discriminator_output_of_cartoon_input, ones)
        d_loss_cartoon_smoothed = self.bce_loss(discriminator_output_of_cartoon_smoothed_input, zeros)
        d_loss_generated_input = self.bce_loss(discriminator_output_of_generated_image_input, zeros)

        d_loss = d_loss_cartoon + d_loss_cartoon_smoothed + d_loss_generated_input

        return d_loss

# Define the Generator Loss
class GeneratorLoss(nn.Module):
    def __init__(self, feature_extractor):
        super(GeneratorLoss, self).__init__()
        self.w = 0.000005
        self.bce_loss = BCELoss()
        self.feature_extractor = feature_extractor
        for param in self.feature_extractor.parameters():
            param.requires_grad = False

    def forward(self, discriminator_output_of_generated_image_input,
                generator_input,
                generator_output,
                is_init_phase=False):

        if is_init_phase:
            g_content_loss = self._content_loss(generator_input, generator_output)
            g_adversarial_loss = 0.0
            g_loss = g_content_loss
        else:
            g_adversarial_loss = self._adversarial_loss_generator_part_only(discriminator_output_of_generated_image_input)
            g_content_loss = self._content_loss(generator_input, generator_output)
            g_loss = g_adversarial_loss + self.w * g_content_loss

        return g_loss

    def _adversarial_loss_generator_part_only(self, discriminator_output_of_generated_image_input):
        ones = torch.ones_like(discriminator_output_of_generated_image_input)
        return self.bce_loss(discriminator_output_of_generated_image_input, ones)

    def _content_loss(self, generator_input, generator_output):
        # Compute the content loss between the VGG features of the input and output
        vgg_input_features = self.feature_extractor(generator_input)
        vgg_output_features = self.feature_extractor(generator_output)
        content_loss = F.l1_loss(vgg_output_features, vgg_input_features)
        return content_loss

# Initialize Loss functions
discriminatorLoss = DiscriminatorLoss()
generatorLoss = GeneratorLoss(feature_extractor)

# Set up optimizers
lr = 0.0002
beta1 = 0.5
beta2 = 0.999

d_optimizer = optim.Adam(D.parameters(), lr=lr, betas=(beta1, beta2))
g_optimizer = optim.Adam(G.parameters(), lr=lr, betas=(beta1, beta2))

# Set up directories for saving results and checkpoints
os.makedirs(os.path.join(project_dir, 'checkpoints/'), exist_ok=True)
intermediate_results_training_path = os.path.join(project_dir, 'intermediate_results/training/')
os.makedirs(intermediate_results_training_path, exist_ok=True)

# Function to save training results
def save_training_result(input, output):
    # input/output has batch-size number of images, get first one and detach from tensor
    image_input = input[0].detach().cpu().numpy()
    image_output = output[0].detach().cpu().numpy()
    # Transpose image from torch.Size([3, 256, 256]) to (256, 256, 3)
    image_input = np.transpose(image_input, (1, 2, 0))
    image_output = np.transpose(image_output, (1, 2, 0))

    # Generate filenames as timestamp
    filename = str(int(time.time()))
    path_input = os.path.join(intermediate_results_training_path, filename + "_input.jpg")
    path_output = os.path.join(intermediate_results_training_path, filename + ".jpg")
    plt.imsave(path_input, image_input)
    plt.imsave(path_output, image_output)

# Check for existing checkpoints
checkpoint_dir = os.path.join(project_dir, 'checkpoints/')
checkpoints = os.listdir(checkpoint_dir)
num_epochs = 200 + 10  # Training + initialization phase
epochs_already_done = 0
best_valid_loss = math.inf
losses = []
validation_losses = []

if len(checkpoints) > 0:
    last_checkpoint = sorted(checkpoints)[-1]
    checkpoint = torch.load(os.path.join(checkpoint_dir, last_checkpoint), map_location=device)
    best_valid_loss = checkpoint['best_valid_loss']
    epochs_already_done = checkpoint['last_epoch']
    losses = checkpoint['losses']
    validation_losses = checkpoint['validation_losses']

    D.load_state_dict(checkpoint['d_state_dict'])
    G.load_state_dict(checkpoint['g_state_dict'])
    d_optimizer.load_state_dict(checkpoint['d_optimizer_state_dict'])
    g_optimizer.load_state_dict(checkpoint['g_optimizer_state_dict'])
    print('Loaded checkpoint {} with g_valid_loss {}, best_valid_loss {}, {} epochs and total no of losses {}'.format(
        last_checkpoint, checkpoint['g_valid_loss'], best_valid_loss, epochs_already_done, len(losses)))

# Define the training function
def train(num_epochs, checkpoint_dir, best_valid_loss, epochs_already_done, losses, validation_losses):
    init_epochs = 10
    print_every = 100
    start_time = time.time()

    # Training loop
    for epoch in tqdm(range(epochs_already_done, num_epochs), desc="Epochs"):
        D.train()
        G.train()
        is_init_phase = epoch < init_epochs

        # Training batches
        for index, ((photo_images, _), (smoothed_cartoon_images, _), (cartoon_images, _)) in enumerate(
                tqdm(zip(photo_dataloader_train, smoothed_cartoon_image_dataloader_train, cartoon_image_dataloader_train),
                     desc="Batches", leave=False)):

            batch_size = photo_images.size(0)
            photo_images = photo_images.to(device)
            smoothed_cartoon_images = smoothed_cartoon_images.to(device)
            cartoon_images = cartoon_images.to(device)

            # Train the discriminator
            d_optimizer.zero_grad()

            d_of_cartoon_input = D(cartoon_images)
            d_of_cartoon_smoothed_input = D(smoothed_cartoon_images)
            generated_images = G(photo_images)
            d_of_generated_image_input = D(generated_images.detach())

            d_loss = discriminatorLoss(d_of_cartoon_input,
                                       d_of_cartoon_smoothed_input,
                                       d_of_generated_image_input)

            d_loss.backward()
            d_optimizer.step()

            # Train the generator
            g_optimizer.zero_grad()

            generated_images = G(photo_images)
            d_of_generated_image_input = D(generated_images)

            g_loss = generatorLoss(d_of_generated_image_input,
                                   photo_images,
                                   generated_images,
                                   is_init_phase=is_init_phase)

            g_loss.backward()
            g_optimizer.step()

            if (index % print_every) == 0:
                losses.append((d_loss.item(), g_loss.item()))
                now = time.time()
                current_run_time = now - start_time
                start_time = now
                print("Epoch {}/{} | d_loss {:6.4f} | g_loss {:6.4f} | time {:2.0f}s | total no. of losses {}".format(
                    epoch+1, num_epochs, d_loss.item(), g_loss.item(), current_run_time, len(losses)))

        save_training_result(photo_images, generated_images)

        # Validation
        D.eval()
        G.eval()
        with torch.no_grad():
            total_g_valid_loss = 0.0
            num_batches = 0
            for batch_index, (photo_images, _) in enumerate(tqdm(photo_dataloader_valid, desc="Validation Batches", leave=False)):
                photo_images = photo_images.to(device)
                generated_images = G(photo_images)
                d_of_generated_image_input = D(generated_images)
                g_valid_loss = generatorLoss(d_of_generated_image_input,
                                             photo_images,
                                             generated_images,
                                             is_init_phase=is_init_phase)
                total_g_valid_loss += g_valid_loss.item()
                num_batches += 1

            avg_g_valid_loss = total_g_valid_loss / num_batches
            validation_losses.append(avg_g_valid_loss)
            print("Epoch {}/{} | validation loss {:6.4f}".format(epoch+1, num_epochs, avg_g_valid_loss))

        # Checkpointing
        if avg_g_valid_loss < best_valid_loss:
            print("Generator loss improved from {} to {}".format(best_valid_loss, avg_g_valid_loss))
            best_valid_loss = avg_g_valid_loss

        checkpoint = {'g_valid_loss': avg_g_valid_loss,
                      'best_valid_loss': best_valid_loss,
                      'losses': losses,
                      'validation_losses': validation_losses,
                      'last_epoch': epoch+1,
                      'd_state_dict': D.state_dict(),
                      'g_state_dict': G.state_dict(),
                      'd_optimizer_state_dict': d_optimizer.state_dict(),
                      'g_optimizer_state_dict': g_optimizer.state_dict()
                     }
        print("Save checkpoint for validation loss of {}".format(avg_g_valid_loss))
        torch.save(checkpoint, os.path.join(checkpoint_dir, 'checkpoint_epoch_{:03d}.pth'.format(epoch+1)))
        if best_valid_loss == avg_g_valid_loss:
            print("Overwrite best checkpoint")
            torch.save(checkpoint, os.path.join(checkpoint_dir, 'best_checkpoint.pth'))

    return losses, validation_losses

# Data loaders
image_size = 256
batch_size = 16

transformer = transforms.Compose([
    transforms.CenterCrop(image_size),
    transforms.ToTensor()  # ToTensor() scales image to [0,1]
])

# Cartoon dataset
cartoon_dataset = ImageFolder('cartoons/', transformer)
len_training_set = math.floor(len(cartoon_dataset) * 0.9)
len_valid_set = len(cartoon_dataset) - len_training_set
training_set, _ = random_split(cartoon_dataset, [len_training_set, len_valid_set])
cartoon_image_dataloader_train = DataLoader(training_set, batch_size=batch_size, shuffle=True, num_workers=0)

# Smoothed cartoon dataset
smoothed_cartoon_dataset = ImageFolder('smoothed_cartoons/', transformer)
len_training_set = math.floor(len(smoothed_cartoon_dataset) * 0.9)
len_valid_set = len(smoothed_cartoon_dataset) - len_training_set
training_set, _ = random_split(smoothed_cartoon_dataset, [len_training_set, len_valid_set])
smoothed_cartoon_image_dataloader_train = DataLoader(training_set, batch_size=batch_size, shuffle=True, num_workers=0)

# Photo dataset
photo_dataset = ImageFolder('cocoimgs/coco_images/', transformer)
len_training_set = math.floor(len(photo_dataset) * 0.9)
len_valid_set = len(photo_dataset) - len_training_set
training_set, validation_set = random_split(photo_dataset, [len_training_set, len_valid_set])
photo_dataloader_train = DataLoader(training_set, batch_size=batch_size, shuffle=True, num_workers=0)
photo_dataloader_valid = DataLoader(validation_set, batch_size=batch_size, shuffle=True, num_workers=0)

# Start training
losses, validation_losses = train(num_epochs, checkpoint_dir, best_valid_loss, epochs_already_done, losses, validation_losses)
# Out:
# No cuda available
# <ipython-input-124-7f3de1503bfa>:127: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   vgg16.load_state_dict(torch.load(path_to_pretrained_vgg16))
# Epochs:   0%|          | 0/210 [00:00<?, ?it/s]
# Batches: 0it [00:00, ?it/s]
